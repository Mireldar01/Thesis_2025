# %%
import rdflib
from rdflib.namespace import RDF, OWL, RDFS
from rdflib import URIRef, Literal
from rapidfuzz import fuzz, process
# these tools which are taken from the rdflib will help with the handeling of the RDF imports

# form the RDF graphs it takes all of the unique predicates and then using that we can get the schema elements that we will use
# such as "label", "date", "author", and so on.
def extract_properties(graph):
    return set(str(p) for _, p, _ in graph)

# this function helps with the readability for the mathcing by cleaning the URIs or literals where they are placed after / and #
# for example like "https://website.com#example" where it will convert it to the "example"
def clean_uri(uri):
    if isinstance(uri, URIRef):
        return str(uri).split("/")[-1].split("#")[-1]
    elif isinstance(uri, Literal):
        return str(uri)
    else:
        return str(uri)

# what this function does is take two lists and finds the most similar list 2 to the list 1 by using the fuzzy method that even works
# when order and form of words are different from each other. after that it will complete will give if matching was successful if the 
# threshold that is set is meet.
def match_labels(labels1, labels2, threshold = 50):
    matches = []
    for label in labels1:
        result = process.extractOne(label, labels2, scorer=fuzz.token_sort_ratio)
        if result is not None:
            match, score, _ = result
            if score >= threshold:
                matches.append((label, match, score))
            
    return matches

# this function allows to get from the given etities rdfs label values but if they are not found then it will take the clean URIs instead
# because thats the next best thing to use. this method is comfortable if for the alignment you want to use the rdf labels instead of the URI
def get_labels(graph, entity):
    labels = []
    for _, _, label in graph.triples((entity, RDFS.label, None)):
        labels.append(str(label))
    if not labels:
        labels.append(str(entity).split("/")[-1].split("#")[-1])
    return labels

# this will load under the ontology1 the first ontology file in the rdf graph format
ontology1 = rdflib.Graph()
ontology1.parse("clariah-tools.ttl", format="turtle")

# similar as the ontology1 the ontology2 will do the same
ontology2 = rdflib.Graph()
ontology2.parse("code-lib.ttl", format="turtle")

# it will extract all of the predicates URIs from the ontologies
properties1 = extract_properties(ontology1)
properties2 = extract_properties(ontology2)

# this will use the function "clean_uri" to make it readable for the matching process
prop_labels1 = [clean_uri(p) for p in properties1]
prop_labels2 = [clean_uri(p) for p in properties2]

# this will use the fuzzy string matching between two ontology sets for the property labels
property_matches = match_labels(prop_labels1, prop_labels2)

# this will print the final matched classes with the paired labels and their scores based on the similarities in the percentages
for p1, p2, score in property_matches:
    print(f"Matched\n" f"{p1} ↔ {p2}\n" f"(score: {score})\n")
# Out:
# Matched
# http://schema.org/codeRepository ↔ https://schema.org/produces
# (score: 74.57627118644068)
#
# Matched
# https://codemeta.github.io/terms/readme ↔ https://codemeta.github.io/terms/referencePublication
# (score: 78.26086956521739)
#
# Matched
# http://schema.org/repository ↔ https://schema.org/author
# (score: 79.24528301886792)
#
# Matched
# http://schema.org/name ↔ https://schema.org/name
# (score: 97.77777777777777)
#
# Matched
# http://schema.org/text ↔ https://schema.org/name
# (score: 84.44444444444444)
#
# Matched
# http://schema.org/license ↔ https://schema.org/name
# (score: 83.33333333333334)
#
# Matched
# https://w3id.org/software-types#executableName ↔ https://w3id.org/software-iodata#producesData
# (score: 70.32967032967032)
#
# Matched
# http://schema.org/releaseNotes ↔ https://schema.org/produces
# (score: 77.19298245614034)
#
# Matched
# https://codemeta.github.io/terms/contIntegration ↔ https://codemeta.github.io/terms/referencePublication
# (score: 79.20792079207921)
#
# Matched
# http://schema.org/review ↔ https://schema.org/name
# (score: 80.85106382978724)
#
# Matched
# http://schema.org/audienceType ↔ https://schema.org/funding
# (score: 78.57142857142857)
#
# Matched
# http://www.w3.org/2000/01/rdf-schema#label ↔ http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# (score: 65.1685393258427)
#
# Matched
# http://schema.org/sourceOrganization ↔ https://schema.org/producer
# (score: 73.01587301587303)
#
# Matched
# http://schema.org/position ↔ https://schema.org/maintainer
# (score: 80.0)
#
# Matched
# http://schema.org/dateCreated ↔ https://schema.org/author
# (score: 77.77777777777779)
#
# Matched
# http://schema.org/applicationSuite ↔ https://schema.org/maintainer
# (score: 76.19047619047619)
#
# Matched
# http://schema.org/version ↔ https://schema.org/name
# (score: 79.16666666666666)
#
# Matched
# http://schema.org/funder ↔ https://schema.org/funding
# (score: 88.0)
#
# Matched
# http://schema.org/funding ↔ https://schema.org/funding
# (score: 98.0392156862745)
#
# Matched
# http://schema.org/downloadUrl ↔ https://schema.org/name
# (score: 76.92307692307692)
#
# Matched
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type ↔ http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# (score: 100.0)
#
# Matched
# http://schema.org/affiliation ↔ https://schema.org/maintainer
# (score: 79.3103448275862)
#
# Matched
# http://www.w3.org/2000/01/rdf-schema#comment ↔ http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# (score: 63.73626373626373)
#
# Matched
# http://schema.org/targetProduct ↔ https://schema.org/produces
# (score: 79.3103448275862)
#
# Matched
# http://schema.org/applicationCategory ↔ https://schema.org/maintainer
# (score: 75.75757575757575)
#
# Matched
# http://schema.org/operatingSystem ↔ https://schema.org/maintainer
# (score: 74.19354838709677)
#
# Matched
# http://schema.org/url ↔ https://schema.org/author
# (score: 86.95652173913044)
#
# Matched
# https://github.com/proycon/codemetapy/log ↔ https://codemeta.github.io/terms/referencePublication
# (score: 51.06382978723405)
#
# Matched
# http://schema.org/maintainer ↔ https://schema.org/maintainer
# (score: 98.24561403508771)
#
# Matched
# http://schema.org/temporal ↔ https://schema.org/author
# (score: 82.35294117647058)
#
# Matched
# http://schema.org/programmingLanguage ↔ https://schema.org/programmingLanguage
# (score: 98.66666666666667)
#
# Matched
# http://schema.org/softwareRequirements ↔ https://schema.org/name
# (score: 68.85245901639344)
#
# Matched
# https://codemeta.github.io/terms/buildInstructions ↔ https://codemeta.github.io/terms/referencePublication
# (score: 77.66990291262135)
#
# Matched
# http://schema.org/email ↔ https://schema.org/name
# (score: 82.6086956521739)
#
# Matched
# http://www.w3.org/2002/07/owl#sameAs ↔ http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# (score: 57.831325301204814)
#
# Matched
# http://schema.org/runtimePlatform ↔ https://schema.org/author
# (score: 75.86206896551724)
#
# Matched
# http://schema.org/familyName ↔ https://schema.org/name
# (score: 82.35294117647058)
#
# Matched
# https://codemeta.github.io/terms/issueTracker ↔ https://codemeta.github.io/terms/referencePublication
# (score: 75.51020408163265)
#
# Matched
# http://schema.org/description ↔ https://schema.org/funding
# (score: 76.36363636363637)
#
# Matched
# http://schema.org/dateModified ↔ https://schema.org/author
# (score: 76.36363636363637)
#
# Matched
# http://schema.org/pageStart ↔ https://schema.org/author
# (score: 80.76923076923077)
#
# Matched
# http://schema.org/contributor ↔ https://schema.org/author
# (score: 81.4814814814815)
#
# Matched
# https://codemeta.github.io/terms/developmentStatus ↔ https://codemeta.github.io/terms/referencePublication
# (score: 75.72815533980582)
#
# Matched
# http://schema.org/producer ↔ https://schema.org/producer
# (score: 98.11320754716981)
#
# Matched
# http://schema.org/identifier ↔ https://schema.org/maintainer
# (score: 84.21052631578947)
#
# Matched
# http://schema.org/spatial ↔ https://schema.org/author
# (score: 80.0)
#
# Matched
# http://schema.org/keywords ↔ https://schema.org/produces
# (score: 79.24528301886792)
#
# Matched
# http://purl.org/dc/terms/relation ↔ http://purl.org/dc/terms/creator
# (score: 92.3076923076923)
#
# Matched
# http://schema.org/parentOrganization ↔ https://schema.org/maintainer
# (score: 73.84615384615385)
#
# Matched
# http://schema.org/location ↔ https://schema.org/author
# (score: 82.35294117647058)
#
# Matched
# http://schema.org/isPartOf ↔ https://schema.org/author
# (score: 78.43137254901961)
#
# Matched
# http://schema.org/softwareHelp ↔ https://schema.org/name
# (score: 75.47169811320755)
#
# Matched
# https://codemeta.github.io/terms/referencePublication ↔ https://codemeta.github.io/terms/referencePublication
# (score: 100.0)
#
# Matched
# http://schema.org/sameAs ↔ https://schema.org/name
# (score: 89.36170212765957)
#
# Matched
# http://schema.org/author ↔ https://schema.org/author
# (score: 97.95918367346938)
#
# Matched
# http://schema.org/encodingFormat ↔ https://schema.org/funding
# (score: 79.3103448275862)
#
# Matched
# http://schema.org/pageEnd ↔ https://schema.org/name
# (score: 83.33333333333334)
#
# Matched
# http://schema.org/datePublished ↔ https://schema.org/publisher
# (score: 84.7457627118644)
#
# Matched
# http://schema.org/givenName ↔ https://schema.org/name
# (score: 88.0)
#
# Matched
# http://schema.org/audience ↔ https://schema.org/funding
# (score: 84.61538461538461)
#
# Matched
# https://github.com/proycon/codemetapy/errors ↔ https://schema.org/produces
# (score: 50.70422535211267)

# %%
import pandas as pd
from rapidfuzz import fuzz, process

threshold = 50
rows = []

for label1 in prop_labels1:
    res = process.extractOne(label1, prop_labels2, scorer=fuzz.token_sort_ratio)
    
    if res:
        label2, score, _ = res
    else:
        label2, score = "—", 0

    rows.append({
        "File 1": "clariah-tools.ttl",
        "File 2": "code-lib.ttl" if label2 != "—" else "",
        "Property from File 1": label1,
        "Property from File 2": label2,
        "Match Score (%)": score,
        "Matched": "Yes" if score >= threshold else "No"
    })

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df_schema = pd.DataFrame(rows)
df_schema
# Out:
#                File 1        File 2  \
# 0   clariah-tools.ttl  code-lib.ttl
# 1   clariah-tools.ttl  code-lib.ttl
# 2   clariah-tools.ttl  code-lib.ttl
# 3   clariah-tools.ttl  code-lib.ttl
# 4   clariah-tools.ttl  code-lib.ttl
# 5   clariah-tools.ttl  code-lib.ttl
# 6   clariah-tools.ttl  code-lib.ttl
# 7   clariah-tools.ttl  code-lib.ttl
# 8   clariah-tools.ttl  code-lib.ttl
# 9   clariah-tools.ttl  code-lib.ttl
# 10  clariah-tools.ttl  code-lib.ttl
# 11  clariah-tools.ttl  code-lib.ttl
# 12  clariah-tools.ttl  code-lib.ttl
# 13  clariah-tools.ttl  code-lib.ttl
# 14  clariah-tools.ttl  code-lib.ttl
# 15  clariah-tools.ttl  code-lib.ttl
# 16  clariah-tools.ttl  code-lib.ttl
# 17  clariah-tools.ttl  code-lib.ttl
# 18  clariah-tools.ttl  code-lib.ttl
# 19  clariah-tools.ttl  code-lib.ttl
# 20  clariah-tools.ttl  code-lib.ttl
# 21  clariah-tools.ttl  code-lib.ttl
# 22  clariah-tools.ttl  code-lib.ttl
# 23  clariah-tools.ttl  code-lib.ttl
# 24  clariah-tools.ttl  code-lib.ttl
# 25  clariah-tools.ttl  code-lib.ttl
# 26  clariah-tools.ttl  code-lib.ttl
# 27  clariah-tools.ttl  code-lib.ttl
# 28  clariah-tools.ttl  code-lib.ttl
# 29  clariah-tools.ttl  code-lib.ttl
# 30  clariah-tools.ttl  code-lib.ttl
# 31  clariah-tools.ttl  code-lib.ttl
# 32  clariah-tools.ttl  code-lib.ttl
# 33  clariah-tools.ttl  code-lib.ttl
# 34  clariah-tools.ttl  code-lib.ttl
# 35  clariah-tools.ttl  code-lib.ttl
# 36  clariah-tools.ttl  code-lib.ttl
# 37  clariah-tools.ttl  code-lib.ttl
# 38  clariah-tools.ttl  code-lib.ttl
# 39  clariah-tools.ttl  code-lib.ttl
# 40  clariah-tools.ttl  code-lib.ttl
# 41  clariah-tools.ttl  code-lib.ttl
# 42  clariah-tools.ttl  code-lib.ttl
# 43  clariah-tools.ttl  code-lib.ttl
# 44  clariah-tools.ttl  code-lib.ttl
# 45  clariah-tools.ttl  code-lib.ttl
# 46  clariah-tools.ttl  code-lib.ttl
# 47  clariah-tools.ttl  code-lib.ttl
# 48  clariah-tools.ttl  code-lib.ttl
# 49  clariah-tools.ttl  code-lib.ttl
# 50  clariah-tools.ttl  code-lib.ttl
# 51  clariah-tools.ttl  code-lib.ttl
# 52  clariah-tools.ttl  code-lib.ttl
# 53  clariah-tools.ttl  code-lib.ttl
# 54  clariah-tools.ttl  code-lib.ttl
# 55  clariah-tools.ttl  code-lib.ttl
# 56  clariah-tools.ttl  code-lib.ttl
# 57  clariah-tools.ttl  code-lib.ttl
# 58  clariah-tools.ttl  code-lib.ttl
# 59  clariah-tools.ttl  code-lib.ttl
# 60  clariah-tools.ttl  code-lib.ttl
#
#                                  Property from File 1  \
# 0                    http://schema.org/codeRepository
# 1             https://codemeta.github.io/terms/readme
# 2                        http://schema.org/repository
# 3                              http://schema.org/name
# 4                              http://schema.org/text
# 5                           http://schema.org/license
# 6      https://w3id.org/software-types#executableName
# 7                      http://schema.org/releaseNotes
# 8    https://codemeta.github.io/terms/contIntegration
# 9                            http://schema.org/review
# 10                     http://schema.org/audienceType
# 11         http://www.w3.org/2000/01/rdf-schema#label
# 12               http://schema.org/sourceOrganization
# 13                         http://schema.org/position
# 14                      http://schema.org/dateCreated
# 15                 http://schema.org/applicationSuite
# 16                          http://schema.org/version
# 17                           http://schema.org/funder
# 18                          http://schema.org/funding
# 19                      http://schema.org/downloadUrl
# 20    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 21                      http://schema.org/affiliation
# 22       http://www.w3.org/2000/01/rdf-schema#comment
# 23                    http://schema.org/targetProduct
# 24              http://schema.org/applicationCategory
# 25                  http://schema.org/operatingSystem
# 26                              http://schema.org/url
# 27          https://github.com/proycon/codemetapy/log
# 28                       http://schema.org/maintainer
# 29                         http://schema.org/temporal
# 30              http://schema.org/programmingLanguage
# 31             http://schema.org/softwareRequirements
# 32  https://codemeta.github.io/terms/buildInstruct...
# 33                            http://schema.org/email
# 34               http://www.w3.org/2002/07/owl#sameAs
# 35                  http://schema.org/runtimePlatform
# 36                       http://schema.org/familyName
# 37      https://codemeta.github.io/terms/issueTracker
# 38                      http://schema.org/description
# 39                     http://schema.org/dateModified
# 40                        http://schema.org/pageStart
# 41                      http://schema.org/contributor
# 42  https://codemeta.github.io/terms/developmentSt...
# 43                         http://schema.org/producer
# 44                       http://schema.org/identifier
# 45                          http://schema.org/spatial
# 46                         http://schema.org/keywords
# 47                  http://purl.org/dc/terms/relation
# 48               http://schema.org/parentOrganization
# 49                         http://schema.org/location
# 50                         http://schema.org/isPartOf
# 51                     http://schema.org/softwareHelp
# 52  https://codemeta.github.io/terms/referencePubl...
# 53                           http://schema.org/sameAs
# 54                           http://schema.org/author
# 55                   http://schema.org/encodingFormat
# 56                          http://schema.org/pageEnd
# 57                    http://schema.org/datePublished
# 58                        http://schema.org/givenName
# 59                         http://schema.org/audience
# 60       https://github.com/proycon/codemetapy/errors
#
#                                  Property from File 2  Match Score (%) Matched
# 0                         https://schema.org/produces        74.576271     Yes
# 1   https://codemeta.github.io/terms/referencePubl...        78.260870     Yes
# 2                           https://schema.org/author        79.245283     Yes
# 3                             https://schema.org/name        97.777778     Yes
# 4                             https://schema.org/name        84.444444     Yes
# 5                             https://schema.org/name        83.333333     Yes
# 6       https://w3id.org/software-iodata#producesData        70.329670     Yes
# 7                         https://schema.org/produces        77.192982     Yes
# 8   https://codemeta.github.io/terms/referencePubl...        79.207921     Yes
# 9                             https://schema.org/name        80.851064     Yes
# 10                         https://schema.org/funding        78.571429     Yes
# 11    http://www.w3.org/1999/02/22-rdf-syntax-ns#type        65.168539     Yes
# 12                        https://schema.org/producer        73.015873     Yes
# 13                      https://schema.org/maintainer        80.000000     Yes
# 14                          https://schema.org/author        77.777778     Yes
# 15                      https://schema.org/maintainer        76.190476     Yes
# 16                            https://schema.org/name        79.166667     Yes
# 17                         https://schema.org/funding        88.000000     Yes
# 18                         https://schema.org/funding        98.039216     Yes
# 19                            https://schema.org/name        76.923077     Yes
# 20    http://www.w3.org/1999/02/22-rdf-syntax-ns#type       100.000000     Yes
# 21                      https://schema.org/maintainer        79.310345     Yes
# 22    http://www.w3.org/1999/02/22-rdf-syntax-ns#type        63.736264     Yes
# 23                        https://schema.org/produces        79.310345     Yes
# 24                      https://schema.org/maintainer        75.757576     Yes
# 25                      https://schema.org/maintainer        74.193548     Yes
# 26                          https://schema.org/author        86.956522     Yes
# 27  https://codemeta.github.io/terms/referencePubl...        51.063830     Yes
# 28                      https://schema.org/maintainer        98.245614     Yes
# 29                          https://schema.org/author        82.352941     Yes
# 30             https://schema.org/programmingLanguage        98.666667     Yes
# 31                            https://schema.org/name        68.852459     Yes
# 32  https://codemeta.github.io/terms/referencePubl...        77.669903     Yes
# 33                            https://schema.org/name        82.608696     Yes
# 34    http://www.w3.org/1999/02/22-rdf-syntax-ns#type        57.831325     Yes
# 35                          https://schema.org/author        75.862069     Yes
# 36                            https://schema.org/name        82.352941     Yes
# 37  https://codemeta.github.io/terms/referencePubl...        75.510204     Yes
# 38                         https://schema.org/funding        76.363636     Yes
# 39                          https://schema.org/author        76.363636     Yes
# 40                          https://schema.org/author        80.769231     Yes
# 41                          https://schema.org/author        81.481481     Yes
# 42  https://codemeta.github.io/terms/referencePubl...        75.728155     Yes
# 43                        https://schema.org/producer        98.113208     Yes
# 44                      https://schema.org/maintainer        84.210526     Yes
# 45                          https://schema.org/author        80.000000     Yes
# 46                        https://schema.org/produces        79.245283     Yes
# 47                   http://purl.org/dc/terms/creator        92.307692     Yes
# 48                      https://schema.org/maintainer        73.846154     Yes
# 49                          https://schema.org/author        82.352941     Yes
# 50                          https://schema.org/author        78.431373     Yes
# 51                            https://schema.org/name        75.471698     Yes
# 52  https://codemeta.github.io/terms/referencePubl...       100.000000     Yes
# 53                            https://schema.org/name        89.361702     Yes
# 54                          https://schema.org/author        97.959184     Yes
# 55                         https://schema.org/funding        79.310345     Yes
# 56                            https://schema.org/name        83.333333     Yes
# 57                       https://schema.org/publisher        84.745763     Yes
# 58                            https://schema.org/name        88.000000     Yes
# 59                         https://schema.org/funding        84.615385     Yes
# 60                        https://schema.org/produces        50.704225     Yes
