# %%
import rdflib
from rdflib.namespace import RDF, OWL, RDFS
from rdflib import URIRef, Literal
from rapidfuzz import fuzz, process

File1 = "clariah-tools.ttl"
File2 = "code-lib.ttl"
setThreshold  = 80

def extract_properties(graph):

    props = set()

    for s, _, _ in graph.triples((None, RDF.type, OWL.ObjectProperty)):
        props.add(str(s))
    for s, _, _ in graph.triples((None, RDF.type, OWL.DatatypeProperty)):
        props.add(str(s))
    for s, _, _ in graph.triples((None, RDF.type, RDF.Property)):
        props.add(str(s))
    if not props:
        props = set(str(p) for p in graph.predicates())

    return props

def clean_uri(uri):
    txt = str(uri)
    return txt.split("#")[-1].split("/")[-1]

def get_prefix(graph, uri):
    qn = graph.namespace_manager.qname(URIRef(uri))
    if ':' in qn:
        return qn.split(':', 1)[0]
    else:
        return qn

def match_labels(labels1, labels2, threshold=setThreshold):
    matches = []
    for label in labels1:
        result = process.extractOne(label, labels2, scorer=fuzz.token_sort_ratio)
        if result:
            match, score, _ = result
            if score >= threshold:
                matches.append((label, match, score))
    return matches

def get_labels(graph, property):
    labels = [str(lbl) for _, _, lbl in graph.triples((URIRef(property), RDFS.label, None))]
    if not labels:
        labels = [property.split("/")[-1].split("#")[-1]]
    return labels

extraction1 = rdflib.Graph()
extraction2 = rdflib.Graph()
extraction1.parse(File1, format="turtle")
extraction2.parse(File2, format="turtle")

props1 = extract_properties(extraction1)
props2 = extract_properties(extraction2)

labels1 = [clean_uri(p) for p in props1]
labels2 = [clean_uri(p) for p in props2]

matches = match_labels(labels1, labels2)

for l1, l2, score in matches:
    uri1 = next(p for p in props1 if clean_uri(p) == l1)
    uri2 = next(p for p in props2 if clean_uri(p) == l2)

    prefix1 = get_prefix(extraction1, uri1)
    prefix2 = get_prefix(extraction2, uri2)

    print(f"Matched: {l1} ↔ {l2} (score: {score})")
    print(f"In {File1}: {prefix1}:{clean_uri(uri1)}  ←  {uri1}")
    print(f"In {File2}: {prefix2}:{clean_uri(uri2)}  ←  {uri2}")
    print("\n Triples using each property:\n")

    print(f" → {File1}:")
    for s, p, o in extraction1.triples((None, URIRef(uri1), None)):
        print(f"{s} {p} {o}")
    print(f"\n → {File2}:")
    for s, p, o in extraction2.triples((None, URIRef(uri2), None)):
        print(f"{s} {p} {o}")

    print("\n" + "-"*60 + "\n")
# Out:
# Matched: programmingLanguage ↔ programmingLanguage (score: 100.0)
# In clariah-tools.ttl: schema1:programmingLanguage  ←  http://schema.org/programmingLanguage
# In code-lib.ttl: sdo:programmingLanguage  ←  https://schema.org/programmingLanguage
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# https://tools.clariah.nl/alpino-service/2.4.1 http://schema.org/programmingLanguage Python
# https://tools.clariah.nl/annorepo-client/0.1.3 http://schema.org/programmingLanguage Python
# https://tools.clariah.nl/asrservice/0.3 http://schema.org/programmingLanguage Python
# https://tools.clariah.nl/auchann/0.2.0 http://schema.org/programmingLanguage Python
# https://tools.clariah.nl/chamd/0.5.12 http://schema.org/programmingLanguage Python
# https://tools.clariah.nl/alpinograph/1.0.5 http://schema.org/programmingLanguage Go
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/programmingLanguage Go
# https://tools.clariah.nl/cesar/unknown http://schema.org/programmingLanguage https://tools.clariah.nl/stub/H-599dce15624737f7
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://schema.org/programmingLanguage Java
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/programmingLanguage SPSS
# https://osf.io/7semh/ https://schema.org/programmingLanguage SPSS
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/programmingLanguage SPSS
# https://osf.io/9b2xh/ https://schema.org/programmingLanguage Stata
# https://doi.org/10.5281/zenodo.7443895 https://schema.org/programmingLanguage Stata
# https://doi.org/10.7910/DVN/5XYHJD https://schema.org/programmingLanguage Stata
# https://doi.org/10.7910/DVN/P39QGO https://schema.org/programmingLanguage Stata
# https://doi.org/10.7910/DVN/VMMMCL https://schema.org/programmingLanguage Stata
# https://github.com/rivm-syso/DIAPER https://schema.org/programmingLanguage Stata
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental https://schema.org/programmingLanguage Stata
# https://osf.io/8mw5s/ https://schema.org/programmingLanguage Stata
# https://osf.io/wnhm7/ https://schema.org/programmingLanguage Stata
# https://osf.io/xt4cq/ https://schema.org/programmingLanguage Stata
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://schema.org/programmingLanguage R
# https://github.com/PerlineDemange/CBS-MR https://schema.org/programmingLanguage R
# https://osf.io/46yqp/ https://schema.org/programmingLanguage R
# https://osf.io/fvqtc/ https://schema.org/programmingLanguage R
# https://osf.io/gmcjv/ https://schema.org/programmingLanguage R
# https://osf.io/ygs72/ https://schema.org/programmingLanguage R
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/programmingLanguage Python
# https://osf.io/eymg8/ https://schema.org/programmingLanguage Stata, R
# https://osf.io/sf4q6/ https://schema.org/programmingLanguage Stata, R
# https://osf.io/y7tnx/ https://schema.org/programmingLanguage Stata, R
# https://osf.io/yt4dj/ https://schema.org/programmingLanguage Stata, R
# https://osf.io/xsgdt/ https://schema.org/programmingLanguage Stata; Mplus
# https://osf.io/zf25j/ https://schema.org/programmingLanguage SPSS, Stata, R
#
# ------------------------------------------------------------
#
# Matched: referencePublication ↔ referencePublication (score: 100.0)
# In clariah-tools.ttl: codemeta:referencePublication  ←  https://codemeta.github.io/terms/referencePublication
# In code-lib.ttl: codemeta:referencePublication  ←  https://codemeta.github.io/terms/referencePublication
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# https://tools.clariah.nl/alpinograph/1.0.5 https://codemeta.github.io/terms/referencePublication https://tools.clariah.nl/stub/H672064490a021b3e
# https://tools.clariah.nl/alud/2.14.0 https://codemeta.github.io/terms/referencePublication https://tools.clariah.nl/stub/H-135468d2078aad8a
# https://tools.clariah.nl/alud/2.14.0 https://codemeta.github.io/terms/referencePublication https://tools.clariah.nl/stub/H495810e52cff797f
# https://tools.clariah.nl/cesar/unknown https://codemeta.github.io/terms/referencePublication https://tools.clariah.nl/stub/H-5dd47d9473a77ce6
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.lanepe.2023.100749
# https://doi.org/10.5281/zenodo.11225732 https://codemeta.github.io/terms/referencePublication https://doi.org/10.1101/2024.05.27.24307982
# https://doi.org/10.5281/zenodo.7443895 https://codemeta.github.io/terms/referencePublication https://doi.org/10.20377/jfr-774
# https://doi.org/10.7910/DVN/5XYHJD https://codemeta.github.io/terms/referencePublication https://doi.org/10.1080/1369183X.2020.1724533
# https://doi.org/10.7910/DVN/P39QGO https://codemeta.github.io/terms/referencePublication https://doi.org/10.1093/esr/jcad027
# https://doi.org/10.7910/DVN/VMMMCL https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.alcr.2021.100433
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://codemeta.github.io/terms/referencePublication https://doi.org/10.1038/s41467-024-45720-2
# https://github.com/PerlineDemange/CBS-MR https://codemeta.github.io/terms/referencePublication https://doi.org/10.1101/2023.01.26.23285029
# https://github.com/UtrechtUniversity/streetview-greenery https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.landurbplan.2021.104181
# https://github.com/rivm-syso/DIAPER https://codemeta.github.io/terms/referencePublication https://doi.org/10.1093/eurpub/ckac170
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental https://codemeta.github.io/terms/referencePublication https://doi.org/10.3368/jhr.1021-11986R1
# https://osf.io/7semh/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1080/02813432.2023.2191653
# https://osf.io/8mw5s/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1007/s00148-024-01029-4
# https://osf.io/eymg8/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.ssresearch.2024.103005
# https://osf.io/fvqtc/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.socnet.2023.03.003
# https://osf.io/gmcjv/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.15195/v10.a14
# https://osf.io/sf4q6/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.rssm.2019.100468
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://codemeta.github.io/terms/referencePublication https://doi.org/10.1371/journal.pone.0292805
# https://osf.io/wnhm7/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1080/14616696.2023.2188550
# https://osf.io/xsgdt/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1038/s41539-024-00225-x
# https://osf.io/xt4cq/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1093/esr/jcac033
# https://osf.io/y7tnx/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1093/esr/jcad075
# https://osf.io/ygs72/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1016/j.envint.2021.106635
# https://osf.io/yt4dj/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1162/euso_a_00020
# https://osf.io/zf25j/ https://codemeta.github.io/terms/referencePublication https://doi.org/10.1038/s41539-024-00283-1
#
# ------------------------------------------------------------
#
# Matched: author ↔ author (score: 100.0)
# In clariah-tools.ttl: schema1:author  ←  http://schema.org/author
# In code-lib.ttl: sdo:author  ←  https://schema.org/author
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# http://dx.doi.org/10.5334/bbi.18 http://schema.org/author https://tools.clariah.nl/stub/H221d4311ba67fa04
# https://doi.org/10.1163/24523666-01000011 http://schema.org/author https://tools.clariah.nl/stub/H221d4311ba67fa04
# http://hdl.handle.net/2066/131547 http://schema.org/author https://tools.clariah.nl/stub/H207e42d0df3ee228
# http://hdl.handle.net/2066/134833 http://schema.org/author https://tools.clariah.nl/stub/H-271cac6e87540556
# https://doi.org/10.5281/zenodo.1007624 http://schema.org/author https://tools.clariah.nl/stub/H-23379d240d381da
# https://doi.org/10.5281/zenodo.1007624 http://schema.org/author https://tools.clariah.nl/stub/H2df669f1d1a9c977
# https://doi.org/10.5281/zenodo.1482791 http://schema.org/author https://tools.clariah.nl/stub/H-7ea000525e77d2ca
# https://doi.org/10.5281/zenodo.2532177 http://schema.org/author https://tools.clariah.nl/stub/H751d01845fadf1b0
# https://doi.org/10.5281/zenodo.3250720 http://schema.org/author https://tools.clariah.nl/stub/H0cb97f98194a2952
# https://doi.org/10.5281/zenodo.3909507 http://schema.org/author https://tools.clariah.nl/stub/H-4812df39416f4210
# https://doi.org/10.5281/zenodo.3909515 http://schema.org/author https://tools.clariah.nl/stub/H-7e3cd543cefcbf6a
# https://doi.org/10.5281/zenodo.3944788 http://schema.org/author https://tools.clariah.nl/stub/H5f413680662be2d3
# https://doi.org/10.5281/zenodo.4011801 http://schema.org/author https://tools.clariah.nl/stub/H-7c396dbc7455a870
# https://doi.org/10.5281/zenodo.4011801 http://schema.org/author https://tools.clariah.nl/stub/H-e4a07200a283979
# https://doi.org/10.5281/zenodo.5803464 http://schema.org/author https://tools.clariah.nl/stub/H-1031e42eb88f27db
# https://doi.org/10.5281/zenodo.5984171 http://schema.org/author https://tools.clariah.nl/stub/H4f96b1e14aff2624
# https://dx.doi.org/10.5334/jors.105 http://schema.org/author https://tools.clariah.nl/stub/H228b51a0d56c59b9
# https://tools.clariah.nl/alpino-service/2.4.1 http://schema.org/author https://tools.clariah.nl/stub/H-72dd6e368bfcca1a
# https://tools.clariah.nl/asrservice/0.3 http://schema.org/author https://tools.clariah.nl/stub/H-72dd6e368bfcca1a
# https://tools.clariah.nl/alpinograph/1.0.5 http://schema.org/author https://tools.clariah.nl/stub/H4667577e67377ad9
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/author https://tools.clariah.nl/stub/H-6ab6711db123cee9
# https://tools.clariah.nl/annorepo-client/0.1.3 http://schema.org/author https://tools.clariah.nl/stub/H-ae9fcd05c8b4549
# https://tools.clariah.nl/asr_nl/0.6.2 http://schema.org/author https://tools.clariah.nl/stub/H2f57a92d1c6be925
# https://tools.clariah.nl/auchann/0.2.0 http://schema.org/author https://tools.clariah.nl/stub/H429f203056dc730a
# https://tools.clariah.nl/cesar/unknown http://schema.org/author https://tools.clariah.nl/stub/H-60ba850fdcd3f515
# https://tools.clariah.nl/chamd/0.5.12 http://schema.org/author https://tools.clariah.nl/stub/H-6ec66a0272e7720b
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://schema.org/author https://tools.clariah.nl/stub/H4f1435ee2bd82b9e
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/author https://orcid.org/0000-0002-7899-2762
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/author https://orcid.org/0000-0002-7899-2762
# https://osf.io/9b2xh/ https://schema.org/author https://orcid.org/0009-0006-0888-5650
# https://osf.io/eymg8/ https://schema.org/author https://orcid.org/0009-0006-0888-5650
# https://osf.io/sf4q6/ https://schema.org/author https://orcid.org/0009-0006-0888-5650
# https://osf.io/y7tnx/ https://schema.org/author https://orcid.org/0009-0006-0888-5650
# https://osf.io/yt4dj/ https://schema.org/author https://orcid.org/0009-0006-0888-5650
# https://doi.org/10.5281/zenodo.11225732 https://schema.org/author https://orcid.org/0000-0001-7331-1000
# https://doi.org/10.5281/zenodo.7443895 https://schema.org/author https://orcid.org/0000-0002-6215-203X
# https://doi.org/10.7910/DVN/5XYHJD https://schema.org/author https://orcid.org/0000-0003-4115-7883
# https://doi.org/10.7910/DVN/P39QGO https://schema.org/author https://orcid.org/0000-0003-4115-7883
# https://doi.org/10.7910/DVN/VMMMCL https://schema.org/author https://orcid.org/0000-0003-4115-7883
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://schema.org/author https://orcid.org/0000-0003-2746-0309
# https://github.com/PerlineDemange/CBS-MR https://schema.org/author https://orcid.org/0000-0002-7061-8354
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/author https://orcid.org/0000-0003-0392-8915
# https://github.com/rivm-syso/DIAPER https://schema.org/author https://orcid.org/0000-0002-8025-040X
# https://osf.io/46yqp/ https://schema.org/author https://orcid.org/0000-0002-8022-6354
# https://osf.io/7semh/ https://schema.org/author https://orcid.org/0000-0002-3491-8990
# https://osf.io/8mw5s/ https://schema.org/author https://orcid.org/0000-0001-8557-5337
# https://osf.io/wnhm7/ https://schema.org/author https://orcid.org/0000-0001-8557-5337
# https://osf.io/fvqtc/ https://schema.org/author https://orcid.org/0000-0002-5898-5557
# https://osf.io/xt4cq/ https://schema.org/author https://orcid.org/0000-0002-5898-5557
# https://osf.io/gmcjv/ https://schema.org/author https://orcid.org/0000-0001-9919-4738
# https://osf.io/xsgdt/ https://schema.org/author https://orcid.org/0000-0002-9877-6215
# https://osf.io/ygs72/ https://schema.org/author https://orcid.org/0000-0001-6978-4737
# https://osf.io/zf25j/ https://schema.org/author https://orcid.org/0000-0003-2323-3782
#
# ------------------------------------------------------------
#
# Matched: type ↔ type (score: 100.0)
# In clariah-tools.ttl: rdf:type  ←  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# In code-lib.ttl: rdf:type  ←  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# http://csvw-converter.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://flat.readthedocs.io/en/latest/?badge=latest http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://flat.readthedocs.io/en/latest/administration_guide.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://flat.readthedocs.io/en/latest/installation_guide.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://flat.readthedocs.io/en/latest/user_guide.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://folia.readthedocs.io/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://foliapy.readthedocs.io/en/latest/?badge=latest http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://textrepo.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://www.sketchengine.co.uk/documentation/wiki/SkE/CorpusQuerying http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://annorepo-python-client.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://annorepo-python-client.readthedocs.io/en/latest/?badge=latest http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://annotation.github.io/text-fabric/tf/index.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://clam.readthedocs.io http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://dane.readthedocs.io/en/latest/examples.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://dane.readthedocs.io/en/latest/intro.html#configuration http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://datasetregister.netwerkdigitaalerfgoed.nl/?lang=en http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://docs.rs/stam http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://folia.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://folia.readthedocs.io/en/latest/form.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://foliapy.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://frognlp.readthedocs.io http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://github.com/CLARIAH/grlc/wiki http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://github.com/CLARIAH/wp6-missieven/blob/master/docs/about.md http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://github.com/ETCBC/shebanq/wiki http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://github.com/MartenPostma/OpenDutchWordnet/raw/master/odwn_documentation.pdf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://kg.odissei.nl/.well-known/genid/8d54600876e2d1be3c00fac3f132d769 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://knaw-huc.github.io/annorepo/docs/api-usage.html http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://mediasuite.clariah.nl/documentation http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://nbviewer.org/github/CLARIAH/wp6-missieven/blob/master/tutorial/start.ipynb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://nbviewer.org/github/ETCBC/bhsa/blob/master/tutorial/start.ipynb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://nbviewer.org/github/Nino-cunei/oldbabylonian/blob/master/tutorial/start.ipynb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://nbviewer.org/github/Nino-cunei/uruk/blob/master/tutorial/start.ipynb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://nbviewer.org/github/annotation/banks/blob/master/programs/convert.ipynb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://pagexml.readthedocs.io/en/latest/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://pagexml.readthedocs.io/en/latest/?badge=latest http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# https://portal.clarin.ivdnt.org/galahad/help http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebSite
# http://dx.doi.org/10.5334/bbi.18 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/ScholarlyArticle
# http://hdl.handle.net/2066/131547 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/ScholarlyArticle
# http://hdl.handle.net/2066/134833 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/ScholarlyArticle
# https://doi.org/10.1163/24523666-01000011 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/ScholarlyArticle
# http://orcid.org/0009-0006-9941-9582 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://github.com/MartijnBNG http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://github.com/jblom http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://github.com/mwigham http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0001-5565-7577 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0001-6854-5646 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0001-7046-7923 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0001-7218-7642 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0001-9510-0802 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0002-0301-2029 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0002-1046-0006 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0002-2713-213X http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0002-3755-5929 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0002-5145-3603 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0003-2493-656X http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# https://orcid.org/0000-0003-4646-5842 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Person
# http://www.w3.org/2004/02/skos/core#Concept http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# http://www.w3.org/2004/02/skos/core#ConceptScheme http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Class
# https://datasetregister.netwerkdigitaalerfgoed.nl/api http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebApplication
# https://tools.clariah.nl/api http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/WebApplication
# https://dig.hum.uu.nl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Organization
# https://huc.knaw.nl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Organization
# https://identifier.overheid.nl/tooi/id/ministerie/mnre1109 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Organization
# https://knaw.nl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Organization
# https://doi.org/10.5281/zenodo.1007624 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.1482791 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.2532177 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.3250720 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.3909507 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.3909515 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.3944788 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.4011801 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.5803464 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://doi.org/10.5281/zenodo.5984171 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Dataset
# https://dx.doi.org/10.5334/jors.105 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/TechArticle
# https://github.com/UtrechtUniversity/ricgraph/blob/main/README.md http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/CreativeWork
# https://iso639-3.sil.org/code/deu http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/eng http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/fra http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/fry http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/ita http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/nld http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/por http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/rus http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/spa http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/swe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://iso639-3.sil.org/code/tur http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Language
# https://tools.clariah.nl/alpino-service/2.4.1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/alpinograph/1.0.5 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/alud/2.14.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/annorepo-client/0.1.3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/asr_nl/0.6.2 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/asrservice/0.3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/auchann/0.2.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/cesar/unknown http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/chamd/0.5.12 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/cobalt/snapshot http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/SoftwareSourceCode
# https://tools.clariah.nl/audience/developers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Audience
# https://tools.clariah.nl/audience/education http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Audience
# https://tools.clariah.nl/audience/religion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Audience
# https://tools.clariah.nl/audience/researchers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Audience
# https://tools.clariah.nl/audience/science-research http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/Audience
# https://tools.clariah.nl/commandlineapplication/alpino2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/auchann/0.2.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/chamd/0.5.12 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/codemeta2html http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/codemetapy http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/conllu2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/cow-tool-cli/1.21 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/cow-tool/1.21 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/dcoi2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2annotatedtxt/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2columns/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2dcoi/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2html/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2rst/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2salt/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2stam/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folia2txt/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliabench/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliacat/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliacorrect/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliacount/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliadocserve/0.7.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaerase/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaeval/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliafreqlist/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaid/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/folialangid/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliamerge/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaquery/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaquery1/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliasetdefinition/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaspec/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaspec2json/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaspec2rdf/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliasplit/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliatextcontent/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliatree/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliaupgrade/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/foliavalidator/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/gecco/0.3.0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/rst2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/sastadev/0.2.3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/tei2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/transcribedspeech2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/txt2folia/2.5.8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/version/0.1.3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#CommandLineApplication
# https://tools.clariah.nl/commandlineapplication/codemeta-server http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://w3id.org/software-types#ServerApplication
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/9b2xh/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.5281/zenodo.11225732 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.5281/zenodo.7443895 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.7910/DVN/5XYHJD http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.7910/DVN/P39QGO http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.7910/DVN/VMMMCL http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://github.com/PerlineDemange/CBS-MR http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://github.com/UtrechtUniversity/streetview-greenery http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://github.com/rivm-syso/DIAPER http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/46yqp/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/7semh/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/8mw5s/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/eymg8/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/fvqtc/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/gmcjv/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/sf4q6/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/wnhm7/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/xsgdt/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/xt4cq/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/y7tnx/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/ygs72/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/yt4dj/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://osf.io/zf25j/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Software
# https://doi.org/10.1016/j.lanepe.2023.100749 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/9b2xh/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.5281/zenodo.11225732 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.5281/zenodo.7443895 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.7910/DVN/5XYHJD http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.7910/DVN/P39QGO http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.7910/DVN/VMMMCL http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://github.com/PerlineDemange/CBS-MR http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://github.com/UtrechtUniversity/streetview-greenery http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://github.com/rivm-syso/DIAPER http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/46yqp/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/7semh/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/8mw5s/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/eymg8/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/fvqtc/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/gmcjv/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/sf4q6/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/wnhm7/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/xsgdt/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/xt4cq/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/y7tnx/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/ygs72/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/yt4dj/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://osf.io/zf25j/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://schema.org/SoftwareSourceCode
# https://doi.org/10.34894/63XWJB http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Dataset
# https://doi.org/10.34894/YQIIQV http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://purl.org/dc/dcmitype/Dataset
#
# ------------------------------------------------------------
#
# Matched: name ↔ name (score: 100.0)
# In clariah-tools.ttl: schema1:name  ←  http://schema.org/name
# In code-lib.ttl: sdo:name  ←  https://schema.org/name
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# http://csvw-converter.readthedocs.io/en/latest/ http://schema.org/name CoW: Converter for CSV on the Web — CSVW Converters 1.0.0 documentation
# http://dx.doi.org/10.5334/bbi.18 http://schema.org/name  The Hebrew Bible as Data: Laboratory – Sharing – Experiences
# http://flat.readthedocs.io/en/latest/?badge=latest http://schema.org/name FLAT - FoLiA Linguistic Annotation Tool - Documentation — FLAT v0.5.2 documentation
# http://flat.readthedocs.io/en/latest/administration_guide.html http://schema.org/name FLAT Administration Guide — FLAT v0.5.2 documentation
# http://flat.readthedocs.io/en/latest/installation_guide.html http://schema.org/name FLAT Installation Guide — FLAT v0.5.2 documentation
# http://flat.readthedocs.io/en/latest/user_guide.html http://schema.org/name FLAT User Guide — FLAT v0.5.2 documentation
# http://folia.readthedocs.io/ http://schema.org/name FoLiA: Format for Linguistic Annotation - Documentation and Reference Guide — FoLiA: Format for Linguistic Annotation v2.0 (rev 9.0) documentation
# https://folia.readthedocs.io/en/latest/ http://schema.org/name FoLiA: Format for Linguistic Annotation - Documentation and Reference Guide — FoLiA: Format for Linguistic Annotation v2.0 (rev 9.0) documentation
# http://foliapy.readthedocs.io/en/latest/?badge=latest http://schema.org/name FoLiA Python Library — FoLiA Python Library v2.5.11, FoLiA v2.5.3 documentation
# https://foliapy.readthedocs.io/en/latest/ http://schema.org/name FoLiA Python Library — FoLiA Python Library v2.5.11, FoLiA v2.5.3 documentation
# http://hdl.handle.net/2066/131547 http://schema.org/name CLAM: Quickly deploy NLP command-line tools on the web
# http://hdl.handle.net/2066/134833 http://schema.org/name T-Scan: a new tool for analyzing Dutch text
# http://spdx.org/licenses/AGPL-3.0-only http://schema.org/name GNU Affero General Public License v3
# http://spdx.org/licenses/Apache-2.0 http://schema.org/name Apache License 2
# http://spdx.org/licenses/BSD-2-Clause http://schema.org/name BSD-2-Clause
# http://spdx.org/licenses/BSD-3-Clause http://schema.org/name BSD-3-Clause
# http://spdx.org/licenses/CC-BY-SA-4.0 http://schema.org/name Creative Commons Attribution Share Alike 4.0 International
# http://spdx.org/licenses/EUPL-1.2 http://schema.org/name European Union Public License
# http://spdx.org/licenses/GPL-2.0-only http://schema.org/name GNU General Public License v2
# http://spdx.org/licenses/GPL-3.0-only http://schema.org/name GNU General Public License v3
# http://spdx.org/licenses/GPL-3.0-or-later http://schema.org/name GNU General Public License v3.0 or later
# http://spdx.org/licenses/MIT http://schema.org/name MIT
# http://textrepo.readthedocs.io/en/latest/ http://schema.org/name Text Repository — Text Repository  documentation
# http://www.etcbc.nl http://schema.org/name Eep Talstra Centre for Bible and Computer
# http://www.sketchengine.co.uk/documentation/wiki/SkE/CorpusQuerying http://schema.org/name Page not found – Sketch Engine
# https://annorepo-python-client.readthedocs.io/en/latest/ http://schema.org/name annorepo-client — annorepo-client 0.1.4 documentation
# https://annorepo-python-client.readthedocs.io/en/latest/?badge=latest http://schema.org/name annorepo-client — annorepo-client 0.1.4 documentation
# https://annotation.github.io/text-fabric/tf/index.html http://schema.org/name Home — Text-Fabric documentation
# https://clam.readthedocs.io http://schema.org/name CLAM Documentation
# https://dane.readthedocs.io/en/latest/examples.html http://schema.org/name Examples — DANE  documentation
# https://dane.readthedocs.io/en/latest/intro.html#configuration http://schema.org/name Introduction — DANE  documentation
# https://datasetregister.netwerkdigitaalerfgoed.nl/api http://schema.org/name Dataset Register OpenAPI
# https://dig.hum.uu.nl http://schema.org/name Digital Humanities Lab
# https://docs.rs/stam http://schema.org/name stam - Rust
# https://doi.org/10.1163/24523666-01000011 http://schema.org/name Coding the Hebrew Bible
# https://doi.org/10.5281/zenodo.1007624 http://schema.org/name BHSA
# https://doi.org/10.5281/zenodo.1482791 http://schema.org/name Uruk
# https://doi.org/10.5281/zenodo.2532177 http://schema.org/name Quran
# https://doi.org/10.5281/zenodo.3250720 http://schema.org/name Northeastern Neo-Aramaic Text-Fabric Corpus
# https://doi.org/10.5281/zenodo.3909507 http://schema.org/name OldBabylonian
# https://doi.org/10.5281/zenodo.3909515 http://schema.org/name OldAssyrian
# https://doi.org/10.5281/zenodo.3944788 http://schema.org/name Dead Sea Scrolls
# https://doi.org/10.5281/zenodo.4011801 http://schema.org/name Missieven
# https://doi.org/10.5281/zenodo.5803464 http://schema.org/name Dhammapada-Latine
# https://doi.org/10.5281/zenodo.5984171 http://schema.org/name NinMed
# https://dx.doi.org/10.5334/jors.105 http://schema.org/name Efficient n-gram, Skipgram and Flexgram Modelling with Colibri Core
# https://folia.readthedocs.io/en/latest/form.html http://schema.org/name Form — FoLiA: Format for Linguistic Annotation v2.0 (rev 9.0) documentation
# https://frognlp.readthedocs.io http://schema.org/name Introduction — frog  documentation
# https://github.com/CLARIAH/grlc/wiki http://schema.org/name grlc Wiki
# https://github.com/CLARIAH/wp6-missieven/blob/master/docs/about.md http://schema.org/name About the Generale Missieven Corpus
# https://github.com/ETCBC/shebanq/wiki http://schema.org/name Home — SHEBANQ documentation
# https://github.com/UtrechtUniversity/ricgraph/blob/main/README.md http://schema.org/name Ricgraph - Research in context graph documentation
# https://huc.knaw.nl http://schema.org/name Humanities Cluster
# https://huc.knaw.nl http://schema.org/name KNAW Humanities Cluster
# https://identifier.overheid.nl/tooi/id/ministerie/mnre1109 http://schema.org/name Ministerie van Onderwijs, Cultuur en Wetenschap
# https://iso639-3.sil.org/code/deu http://schema.org/name German
# https://iso639-3.sil.org/code/eng http://schema.org/name English
# https://iso639-3.sil.org/code/fra http://schema.org/name French
# https://iso639-3.sil.org/code/fry http://schema.org/name Frisian
# https://iso639-3.sil.org/code/ita http://schema.org/name Italian
# https://iso639-3.sil.org/code/nld http://schema.org/name Dutch
# https://iso639-3.sil.org/code/por http://schema.org/name Portuguese
# https://iso639-3.sil.org/code/rus http://schema.org/name Russian
# https://iso639-3.sil.org/code/spa http://schema.org/name Spanish
# https://iso639-3.sil.org/code/swe http://schema.org/name Swedish
# https://iso639-3.sil.org/code/tur http://schema.org/name Turkish
# https://knaw-huc.github.io/annorepo/docs/api-usage.html http://schema.org/name AnnoRepo API Usage
# https://knaw.nl http://schema.org/name KNAW
# https://mediasuite.clariah.nl/documentation http://schema.org/name Media Suite Documentation
# https://nbviewer.org/github/CLARIAH/wp6-missieven/blob/master/tutorial/start.ipynb http://schema.org/name Jupyter Notebook: how to work with the Generale Missieven Corpus
# https://nbviewer.org/github/CLARIAH/wp6-missieven/blob/master/tutorial/start.ipynb http://schema.org/name Tutorial for working with the General Missives (Dutch colonial history); family of Jupyter Notebooks
# ...
# https://tools.clariah.nl/commandlineapplication/foliaerase/2.5.8 http://schema.org/name foliaerase
# https://tools.clariah.nl/commandlineapplication/foliaeval/2.5.8 http://schema.org/name foliaeval
# https://tools.clariah.nl/commandlineapplication/foliafreqlist/2.5.8 http://schema.org/name foliafreqlist
# https://tools.clariah.nl/commandlineapplication/foliaid/2.5.8 http://schema.org/name foliaid
# https://tools.clariah.nl/commandlineapplication/folialangid/2.5.8 http://schema.org/name folialangid
# https://tools.clariah.nl/commandlineapplication/foliamerge/2.5.8 http://schema.org/name foliamerge
# https://tools.clariah.nl/commandlineapplication/foliaquery/2.5.8 http://schema.org/name foliaquery
# https://tools.clariah.nl/commandlineapplication/foliaquery1/2.5.8 http://schema.org/name foliaquery1
# https://tools.clariah.nl/commandlineapplication/foliasetdefinition/2.5.8 http://schema.org/name foliasetdefinition
# https://tools.clariah.nl/commandlineapplication/foliaspec/2.5.8 http://schema.org/name foliaspec
# https://tools.clariah.nl/commandlineapplication/foliaspec2json/2.5.8 http://schema.org/name foliaspec2json
# https://tools.clariah.nl/commandlineapplication/foliaspec2rdf/2.5.8 http://schema.org/name foliaspec2rdf
# https://tools.clariah.nl/commandlineapplication/foliasplit/2.5.8 http://schema.org/name foliasplit
# https://tools.clariah.nl/commandlineapplication/foliatextcontent/2.5.8 http://schema.org/name foliatextcontent
# https://tools.clariah.nl/commandlineapplication/foliatree/2.5.8 http://schema.org/name foliatree
# https://tools.clariah.nl/commandlineapplication/foliaupgrade/2.5.8 http://schema.org/name foliaupgrade
# https://tools.clariah.nl/commandlineapplication/foliavalidator/2.5.8 http://schema.org/name foliavalidator
# https://tools.clariah.nl/commandlineapplication/gecco/0.3.0 http://schema.org/name gecco
# https://tools.clariah.nl/commandlineapplication/rst2folia/2.5.8 http://schema.org/name rst2folia
# https://tools.clariah.nl/commandlineapplication/sastadev/0.2.3 http://schema.org/name sastadev
# https://tools.clariah.nl/commandlineapplication/tei2folia/2.5.8 http://schema.org/name tei2folia
# https://tools.clariah.nl/commandlineapplication/transcribedspeech2folia/2.5.8 http://schema.org/name transcribedspeech2folia
# https://tools.clariah.nl/commandlineapplication/txt2folia/2.5.8 http://schema.org/name txt2folia
# https://tools.clariah.nl/commandlineapplication/version/0.1.3 http://schema.org/name version
# https://tools.clariah.nl/commandlineapplication/version/0.5.1 http://schema.org/name version
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/name Diversity in the pathway from medical student to specialist in the Netherlands: a retrospective cohort study
# https://osf.io/9b2xh/ https://schema.org/name Netherlands Integrated Database of Inequality in Organizations (NIDIO)
# https://doi.org/10.5281/zenodo.11225732 https://schema.org/name Enhancing Accuracy in Country-Wide Agent-Based Epidemiological Modeling through the Application of 17 Million Individual-Level Microdata Points
# https://doi.org/10.5281/zenodo.7443895 https://schema.org/name Children's strains, parents' pains? How adult children's union dissolution influences older parents' health
# https://doi.org/10.7910/DVN/5XYHJD https://schema.org/name The intergenerational impact of naturalisation reforms: the citizenship status of children of immigrants in the Netherlands, 1995-2016
# https://doi.org/10.7910/DVN/P39QGO https://schema.org/name Timing of citizenship acquisition and immigrants' children educational outcomes: a family fixed-effects approach
# https://doi.org/10.7910/DVN/VMMMCL https://schema.org/name Citizenship and education trajectories among children of immigrants: A transition-oriented sequence analysis
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://schema.org/name Inequalities in Healthcare use during the COVID-19 pandemic
# https://github.com/PerlineDemange/CBS-MR https://schema.org/name Evaluating the causal relationship between educational attainment and mental health
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/name NEEDS (Dynamic Urban Environmental Exposures on Depression and Suicide)
# https://github.com/rivm-syso/DIAPER https://schema.org/name Defining vulnerability subgroups among pregnant women using pre-pregnancy information: a latent class analysis
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental https://schema.org/name Medication of Postpartum Depression and Maternal Outcomes: Evidence from Geographic Variation in Dutch Prescribing
# https://osf.io/46yqp/ https://schema.org/name Statistics Netherlands (CBS) Microdata: Merging datasets (generic)
# https://osf.io/7semh/ https://schema.org/name Sex and gender differences in primary care help-seeking for common somatic symptoms: a longitudinal study
# https://osf.io/8mw5s/ https://schema.org/name Less for more? Cuts to child benefits, family adjustments, and long-run child outcomes in larger families
# https://osf.io/eymg8/ https://schema.org/name Occupations and careers within organizations: Do organizations facilitate unequal wage growth?
# https://osf.io/fvqtc/ https://schema.org/name Knowing me, knowing you: Socio-economic status and (segregation in) peer and parental networks in primary school
# https://osf.io/gmcjv/ https://schema.org/name Money, Birth, Gender: Explaining Unequal Earnings Trajectories following Parenthood
# https://osf.io/sf4q6/ https://schema.org/name Occupations, organizations, and the structure of wage inequality in the Netherlands
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/name Inequality of opportunity in selection procedures limits diversity in higher education: An intersectional study of Dutch selective higher education programs
# https://osf.io/wnhm7/ https://schema.org/name The timing of parental unemployment, insurance and children's education
# https://osf.io/xsgdt/ https://schema.org/name Gene-environment interaction analysis of school quality and educational inequality
# https://osf.io/xt4cq/ https://schema.org/name Let's Stick Together: Peer Effects in Secondary School Choice and Variations by Student Socio-Economic Background
# https://osf.io/y7tnx/ https://schema.org/name Temporary employment and wage inequality over the life course
# https://osf.io/ygs72/ https://schema.org/name Multiple environmental exposures along daily mobility paths and depressive symptoms: A smartphone-based tracking study
# https://osf.io/yt4dj/ https://schema.org/name Essential Workers and Wage Inequality: Wage Differentials before and during the Covid-19 Pandemic, 2006 to 2022
# https://osf.io/zf25j/ https://schema.org/name Inequality in pandemic effects on school track placement and the role of social and academic embeddedness
#
# ------------------------------------------------------------
#
# Matched: funding ↔ funding (score: 100.0)
# In clariah-tools.ttl: schema1:funding  ←  http://schema.org/funding
# In code-lib.ttl: sdo:funding  ←  https://schema.org/funding
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/funding https://tools.clariah.nl/stub/H-4018924ead47559b
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://schema.org/funding https://tools.clariah.nl/stub/H0049fcdd85d04a19
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/funding MAD2022
# https://github.com/PerlineDemange/CBS-MR https://schema.org/funding MAD2022
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/funding MAD2022
# https://osf.io/zf25j/ https://schema.org/funding MAD2022
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/funding MAD2020
# https://osf.io/ygs72/ https://schema.org/funding MAD2020
# https://osf.io/8mw5s/ https://schema.org/funding MAG2021
# https://osf.io/gmcjv/ https://schema.org/funding MAD2021
# https://osf.io/xsgdt/ https://schema.org/funding MAG2019
#
# ------------------------------------------------------------
#
# Matched: producer ↔ producer (score: 100.0)
# In clariah-tools.ttl: schema1:producer  ←  http://schema.org/producer
# In code-lib.ttl: sdo:producer  ←  https://schema.org/producer
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# https://tools.clariah.nl/alpino-service/2.4.1 http://schema.org/producer https://tools.clariah.nl/org/knaw-humanities-cluster-clst-radboud-university
# https://tools.clariah.nl/alpinograph/1.0.5 http://schema.org/producer https://tools.clariah.nl/stub/H5a458f469b56ea98
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/producer https://tools.clariah.nl/stub/H-4353f5e8f8edc2f6
# https://tools.clariah.nl/annorepo-client/0.1.3 http://schema.org/producer https://tools.clariah.nl/org/knaw-humanities-cluster
# https://tools.clariah.nl/asr_nl/0.6.2 http://schema.org/producer https://www.ru.nl/clst
# https://tools.clariah.nl/asrservice/0.3 http://schema.org/producer https://tools.clariah.nl/org/open-spraaktechnologie
# https://tools.clariah.nl/auchann/0.2.0 http://schema.org/producer https://tools.clariah.nl/org/uu-digital-humanities-lab
# https://tools.clariah.nl/chamd/0.5.12 http://schema.org/producer https://tools.clariah.nl/org/uu-digital-humanities-lab
# https://tools.clariah.nl/cesar/unknown http://schema.org/producer https://www.ru.nl/humanitieslab/technical-support-group
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://schema.org/producer https://tools.clariah.nl/stub/H01b80794b2defc8b
# https://tools.clariah.nl/cobalt/snapshot http://schema.org/producer https://tools.clariah.nl/org/dutch-language-institute
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8642
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8642
# https://osf.io/9b2xh/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9607
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8951
# https://github.com/PerlineDemange/CBS-MR https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8590
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8217
# https://osf.io/ygs72/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8217
# https://github.com/rivm-syso/DIAPER https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8552
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8666
# https://osf.io/7semh/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8656
# https://osf.io/8mw5s/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9102
# https://osf.io/eymg8/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8419
# https://osf.io/sf4q6/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8419
# https://osf.io/y7tnx/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8419
# https://osf.io/yt4dj/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/8419
# https://osf.io/fvqtc/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9232
# https://osf.io/xt4cq/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9232
# https://osf.io/zf25j/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9232
# https://osf.io/gmcjv/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/9120
# https://osf.io/wnhm7/ https://schema.org/producer https://w3id.org/odissei/ns/kg/cbs/project/SES/208008SSBONT_SEC1
#
# ------------------------------------------------------------
#
# Matched: maintainer ↔ maintainer (score: 100.0)
# In clariah-tools.ttl: schema1:maintainer  ←  http://schema.org/maintainer
# In code-lib.ttl: sdo:maintainer  ←  https://schema.org/maintainer
#
#  Triples using each property:
#
#  → clariah-tools.ttl:
# https://tools.clariah.nl/alpino-service/2.4.1 http://schema.org/maintainer https://tools.clariah.nl/person/maarten-van-gompel
# https://tools.clariah.nl/asrservice/0.3 http://schema.org/maintainer https://tools.clariah.nl/person/maarten-van-gompel
# https://tools.clariah.nl/alpinograph/1.0.5 http://schema.org/maintainer https://tools.clariah.nl/stub/H-13011a6c575d3c86
# https://tools.clariah.nl/alpinograph/1.0.5 http://schema.org/maintainer https://tools.clariah.nl/stub/H6ed411b86949c557
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/maintainer https://tools.clariah.nl/stub/H-4252c559397b2065
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/maintainer https://tools.clariah.nl/stub/H189f83e1157e53db
# https://tools.clariah.nl/alud/2.14.0 http://schema.org/maintainer https://tools.clariah.nl/stub/H646501f59d7a99c8
# https://tools.clariah.nl/annorepo-client/0.1.3 http://schema.org/maintainer https://tools.clariah.nl/person/bram-buitendijk
# https://tools.clariah.nl/asr_nl/0.6.2 http://schema.org/maintainer https://tools.clariah.nl/stub/H-6616991b63360edb
# https://tools.clariah.nl/auchann/0.2.0 http://schema.org/maintainer https://tools.clariah.nl/person/digital-humanities-lab
# https://tools.clariah.nl/cesar/unknown http://schema.org/maintainer https://tools.clariah.nl/stub/H-1f8f0108bdc02a80
# https://tools.clariah.nl/chamd/0.5.12 http://schema.org/maintainer https://tools.clariah.nl/stub/H2da7dcbb42d9405a
# https://tools.clariah.nl/clariah-fcs-endpoints/0.1 http://schema.org/maintainer https://tools.clariah.nl/person/mathieu-fannee
#
#  → code-lib.ttl:
# https://doi.org/10.1016/j.lanepe.2023.100749 https://schema.org/maintainer Lianne Mulder
# https://osf.io/uzcrw?view_only=7114b77c9f8b4062ab31f885ce331a65 https://schema.org/maintainer Lianne Mulder
# https://osf.io/9b2xh/ https://schema.org/maintainer Christoph Janietz
# https://osf.io/eymg8/ https://schema.org/maintainer Christoph Janietz
# https://osf.io/sf4q6/ https://schema.org/maintainer Christoph Janietz
# https://osf.io/y7tnx/ https://schema.org/maintainer Christoph Janietz
# https://osf.io/yt4dj/ https://schema.org/maintainer Christoph Janietz
# https://doi.org/10.5281/zenodo.11225732 https://schema.org/maintainer Ahmad Hesam
# https://doi.org/10.5281/zenodo.7443895 https://schema.org/maintainer Damiano Uccheddu
# https://doi.org/10.7910/DVN/5XYHJD https://schema.org/maintainer Marie Labussière
# https://doi.org/10.7910/DVN/P39QGO https://schema.org/maintainer Marie Labussière
# https://doi.org/10.7910/DVN/VMMMCL https://schema.org/maintainer Marie Labussière
# https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19 https://schema.org/maintainer Mark Verhagen
# https://github.com/PerlineDemange/CBS-MR https://schema.org/maintainer Perline Demange
# https://github.com/UtrechtUniversity/streetview-greenery https://schema.org/maintainer Marco Helbich
# https://github.com/rivm-syso/DIAPER https://schema.org/maintainer Joyce Molenaar
# https://jhr.uwpress.org/content/early/2023/06/01/jhr.1021-11986R1/tab-supplemental https://schema.org/maintainer Esmée Zwiers
# https://osf.io/46yqp/ https://schema.org/maintainer Erwin Gielens
# https://osf.io/7semh/ https://schema.org/maintainer Aranka van Ballering
# https://osf.io/8mw5s/ https://schema.org/maintainer Gabriele Mari
# https://osf.io/wnhm7/ https://schema.org/maintainer Gabriele Mari
# https://osf.io/fvqtc/ https://schema.org/maintainer Dieuwke Zwier
# https://osf.io/xt4cq/ https://schema.org/maintainer Dieuwke Zwier
# https://osf.io/gmcjv/ https://schema.org/maintainer Weverthon Barbosa Machado
# https://osf.io/xsgdt/ https://schema.org/maintainer Kim Stienstra
# https://osf.io/ygs72/ https://schema.org/maintainer Hannah Roberts
# https://osf.io/zf25j/ https://schema.org/maintainer Herman G. van de Werfhorst
#
# ------------------------------------------------------------

# %%
import pandas as pd


threshold = setThreshold
rows = []

for label1 in labels1:
    
    res = process.extractOne(label1, labels2, scorer=fuzz.token_sort_ratio)
    if res:
        label2, score, _ = res
    else:
        label2, score = "—", 0
    
    uri1 = next(p for p in props1 if clean_uri(p) == label1)
    prefix1 = get_prefix(extraction1, uri1)

    if label2 != "—":
        uri2 = next(p for p in props2 if clean_uri(p) == label2)
        prefix2 = get_prefix(extraction2, uri2)
    else:
        prefix2 = ""

    rows.append({
        "File 1": "clariah-tools.ttl",
        "File 2": "code-lib.ttl" if label2 != "—" else "",
        "Prefix File 1": prefix1,
        "Property from File 1": label1,
        "Prefix File 2": prefix2,
        "Property from File 2": label2,
        "Match Score (%)": score,
        "Matched": "Yes" if score >= threshold else "No"
    })

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(rows)

df
# Out:
#                File 1        File 2 Prefix File 1  Property from File 1  \
# 0   clariah-tools.ttl  code-lib.ttl       schema1   programmingLanguage
# 1   clariah-tools.ttl  code-lib.ttl       schema1          softwareHelp
# 2   clariah-tools.ttl  code-lib.ttl       schema1        codeRepository
# 3   clariah-tools.ttl  code-lib.ttl      codemeta     developmentStatus
# 4   clariah-tools.ttl  code-lib.ttl       schema1          dateModified
# 5   clariah-tools.ttl  code-lib.ttl       schema1  softwareRequirements
# 6   clariah-tools.ttl  code-lib.ttl      codemeta       contIntegration
# 7   clariah-tools.ttl  code-lib.ttl       schema1            repository
# 8   clariah-tools.ttl  code-lib.ttl           dct              relation
# 9   clariah-tools.ttl  code-lib.ttl           ns1        executableName
# 10  clariah-tools.ttl  code-lib.ttl           owl                sameAs
# 11  clariah-tools.ttl  code-lib.ttl       schema1           affiliation
# 12  clariah-tools.ttl  code-lib.ttl      codemeta  referencePublication
# 13  clariah-tools.ttl  code-lib.ttl       schema1                author
# 14  clariah-tools.ttl  code-lib.ttl       schema1      applicationSuite
# 15  clariah-tools.ttl  code-lib.ttl       schema1            identifier
# 16  clariah-tools.ttl  code-lib.ttl       schema1               pageEnd
# 17  clariah-tools.ttl  code-lib.ttl       schema1              position
# 18  clariah-tools.ttl  code-lib.ttl           ns2                   log
# 19  clariah-tools.ttl  code-lib.ttl           ns2                errors
# 20  clariah-tools.ttl  code-lib.ttl       schema1                review
# 21  clariah-tools.ttl  code-lib.ttl       schema1        encodingFormat
# 22  clariah-tools.ttl  code-lib.ttl       schema1       operatingSystem
# 23  clariah-tools.ttl  code-lib.ttl           rdf                  type
# 24  clariah-tools.ttl  code-lib.ttl       schema1       runtimePlatform
# 25  clariah-tools.ttl  code-lib.ttl       schema1               spatial
# 26  clariah-tools.ttl  code-lib.ttl           owl                sameAs
# 27  clariah-tools.ttl  code-lib.ttl       schema1                  text
# 28  clariah-tools.ttl  code-lib.ttl       schema1             givenName
# 29  clariah-tools.ttl  code-lib.ttl       schema1    parentOrganization
# 30  clariah-tools.ttl  code-lib.ttl       schema1         datePublished
# 31  clariah-tools.ttl  code-lib.ttl          rdfs                 label
# 32  clariah-tools.ttl  code-lib.ttl      codemeta          issueTracker
# 33  clariah-tools.ttl  code-lib.ttl       schema1           dateCreated
# 34  clariah-tools.ttl  code-lib.ttl       schema1              audience
# 35  clariah-tools.ttl  code-lib.ttl       schema1            familyName
# 36  clariah-tools.ttl  code-lib.ttl       schema1           description
# 37  clariah-tools.ttl  code-lib.ttl          rdfs               comment
# 38  clariah-tools.ttl  code-lib.ttl       schema1         targetProduct
# 39  clariah-tools.ttl  code-lib.ttl       schema1                   url
# 40  clariah-tools.ttl  code-lib.ttl       schema1           contributor
# 41  clariah-tools.ttl  code-lib.ttl       schema1              keywords
# 42  clariah-tools.ttl  code-lib.ttl       schema1             pageStart
# 43  clariah-tools.ttl  code-lib.ttl       schema1    sourceOrganization
# 44  clariah-tools.ttl  code-lib.ttl       schema1                 email
# 45  clariah-tools.ttl  code-lib.ttl      codemeta     buildInstructions
# 46  clariah-tools.ttl  code-lib.ttl       schema1           downloadUrl
# 47  clariah-tools.ttl  code-lib.ttl       schema1          releaseNotes
# 48  clariah-tools.ttl  code-lib.ttl       schema1                  name
# 49  clariah-tools.ttl  code-lib.ttl       schema1              temporal
# 50  clariah-tools.ttl  code-lib.ttl       schema1               funding
# 51  clariah-tools.ttl  code-lib.ttl       schema1               license
# 52  clariah-tools.ttl  code-lib.ttl      codemeta                readme
# 53  clariah-tools.ttl  code-lib.ttl       schema1              location
# 54  clariah-tools.ttl  code-lib.ttl       schema1                funder
# 55  clariah-tools.ttl  code-lib.ttl       schema1              isPartOf
# 56  clariah-tools.ttl  code-lib.ttl       schema1               version
# 57  clariah-tools.ttl  code-lib.ttl       schema1   applicationCategory
# 58  clariah-tools.ttl  code-lib.ttl       schema1          audienceType
# 59  clariah-tools.ttl  code-lib.ttl       schema1              producer
# 60  clariah-tools.ttl  code-lib.ttl       schema1            maintainer
#
#    Prefix File 2  Property from File 2  Match Score (%) Matched
# 0            sdo   programmingLanguage       100.000000     Yes
# 1            dct        isReferencedBy        38.461538      No
# 2            dct               creator        47.619048      No
# 3       codemeta  referencePublication        32.432432      No
# 4            sdo            maintainer        36.363636      No
# 5            dct              requires        57.142857      No
# 6            dct               creator        45.454545      No
# 7            dct               creator        58.823529      No
# 8            dct               creator        66.666667      No
# 9       codemeta  referencePublication        41.176471      No
# 10           sdo                  name        60.000000      No
# 11      codemeta  referencePublication        51.612903      No
# 12      codemeta  referencePublication       100.000000     Yes
# 13           sdo                author       100.000000     Yes
# 14           sdo            maintainer        46.153846      No
# 15           sdo            maintainer        60.000000      No
# 16           dct              language        40.000000      No
# 17           sdo            maintainer        44.444444      No
# 18           dct              language        36.363636      No
# 19           dct               creator        46.153846      No
# 20           dct              requires        57.142857      No
# 21           sdo               funding        47.619048      No
# 22           sdo   programmingLanguage        41.176471      No
# 23           rdf                  type       100.000000     Yes
# 24           dct               creator        54.545455      No
# 25           dct                 title        50.000000      No
# 26           sdo                  name        60.000000      No
# 27           rdf                  type        50.000000      No
# 28           sdo                  name        61.538462      No
# 29      codemeta  referencePublication        52.631579      No
# 30           dct             publisher        63.636364      No
# 31           dct              language        46.153846      No
# 32           dct        isReferencedBy        46.153846      No
# 33           dct               creator        44.444444      No
# 34           sdo               funding        53.333333      No
# 35           sdo                  name        42.857143      No
# 36      codemeta  referencePublication        45.161290      No
# 37           dct               creator        42.857143      No
# 38         sftio          producesData        48.000000      No
# 39           sdo                author        44.444444      No
# 40           dct               creator        55.555556      No
# 41           dct               creator        40.000000      No
# 42           sdo            maintainer        42.105263      No
# 43      codemeta  referencePublication        52.631579      No
# 44           dct                 title        40.000000      No
# 45      codemeta  referencePublication        37.837838      No
# 46           sdo              producer        31.578947      No
# 47           dct               creator        42.105263      No
# 48           sdo                  name       100.000000     Yes
# 49           sdo                author        42.857143      No
# 50           sdo               funding       100.000000     Yes
# 51           dct             publisher        50.000000      No
# 52           sdo                  name        60.000000      No
# 53           dct               creator        53.333333      No
# 54           sdo               funding        61.538462      No
# 55           dct             publisher        35.294118      No
# 56           dct              requires        40.000000      No
# 57           sdo            maintainer        48.275862      No
# 58           dct        isReferencedBy        46.153846      No
# 59           sdo              producer       100.000000     Yes
# 60           sdo            maintainer       100.000000     Yes

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

matched_df   = df[df['Matched'] == 'Yes']
unmatched_df = df[df['Matched'] == 'No']

print("Matched Properties")
display(matched_df)

print("Unmatched Properties")
display(unmatched_df)
# Out:
# Matched Properties
#                File 1        File 2 Prefix File 1  Property from File 1  \
# 0   clariah-tools.ttl  code-lib.ttl       schema1   programmingLanguage
# 12  clariah-tools.ttl  code-lib.ttl      codemeta  referencePublication
# 13  clariah-tools.ttl  code-lib.ttl       schema1                author
# 23  clariah-tools.ttl  code-lib.ttl           rdf                  type
# 48  clariah-tools.ttl  code-lib.ttl       schema1                  name
# 50  clariah-tools.ttl  code-lib.ttl       schema1               funding
# 59  clariah-tools.ttl  code-lib.ttl       schema1              producer
# 60  clariah-tools.ttl  code-lib.ttl       schema1            maintainer
#
#    Prefix File 2  Property from File 2  Match Score (%) Matched
# 0            sdo   programmingLanguage            100.0     Yes
# 12      codemeta  referencePublication            100.0     Yes
# 13           sdo                author            100.0     Yes
# 23           rdf                  type            100.0     Yes
# 48           sdo                  name            100.0     Yes
# 50           sdo               funding            100.0     Yes
# 59           sdo              producer            100.0     Yes
# 60           sdo            maintainer            100.0     Yes
# Unmatched Properties
#                File 1        File 2 Prefix File 1  Property from File 1  \
# 1   clariah-tools.ttl  code-lib.ttl       schema1          softwareHelp
# 2   clariah-tools.ttl  code-lib.ttl       schema1        codeRepository
# 3   clariah-tools.ttl  code-lib.ttl      codemeta     developmentStatus
# 4   clariah-tools.ttl  code-lib.ttl       schema1          dateModified
# 5   clariah-tools.ttl  code-lib.ttl       schema1  softwareRequirements
# 6   clariah-tools.ttl  code-lib.ttl      codemeta       contIntegration
# 7   clariah-tools.ttl  code-lib.ttl       schema1            repository
# 8   clariah-tools.ttl  code-lib.ttl           dct              relation
# 9   clariah-tools.ttl  code-lib.ttl           ns1        executableName
# 10  clariah-tools.ttl  code-lib.ttl           owl                sameAs
# 11  clariah-tools.ttl  code-lib.ttl       schema1           affiliation
# 14  clariah-tools.ttl  code-lib.ttl       schema1      applicationSuite
# 15  clariah-tools.ttl  code-lib.ttl       schema1            identifier
# 16  clariah-tools.ttl  code-lib.ttl       schema1               pageEnd
# 17  clariah-tools.ttl  code-lib.ttl       schema1              position
# 18  clariah-tools.ttl  code-lib.ttl           ns2                   log
# 19  clariah-tools.ttl  code-lib.ttl           ns2                errors
# 20  clariah-tools.ttl  code-lib.ttl       schema1                review
# 21  clariah-tools.ttl  code-lib.ttl       schema1        encodingFormat
# 22  clariah-tools.ttl  code-lib.ttl       schema1       operatingSystem
# 24  clariah-tools.ttl  code-lib.ttl       schema1       runtimePlatform
# 25  clariah-tools.ttl  code-lib.ttl       schema1               spatial
# 26  clariah-tools.ttl  code-lib.ttl           owl                sameAs
# 27  clariah-tools.ttl  code-lib.ttl       schema1                  text
# 28  clariah-tools.ttl  code-lib.ttl       schema1             givenName
# 29  clariah-tools.ttl  code-lib.ttl       schema1    parentOrganization
# 30  clariah-tools.ttl  code-lib.ttl       schema1         datePublished
# 31  clariah-tools.ttl  code-lib.ttl          rdfs                 label
# 32  clariah-tools.ttl  code-lib.ttl      codemeta          issueTracker
# 33  clariah-tools.ttl  code-lib.ttl       schema1           dateCreated
# 34  clariah-tools.ttl  code-lib.ttl       schema1              audience
# 35  clariah-tools.ttl  code-lib.ttl       schema1            familyName
# 36  clariah-tools.ttl  code-lib.ttl       schema1           description
# 37  clariah-tools.ttl  code-lib.ttl          rdfs               comment
# 38  clariah-tools.ttl  code-lib.ttl       schema1         targetProduct
# 39  clariah-tools.ttl  code-lib.ttl       schema1                   url
# 40  clariah-tools.ttl  code-lib.ttl       schema1           contributor
# 41  clariah-tools.ttl  code-lib.ttl       schema1              keywords
# 42  clariah-tools.ttl  code-lib.ttl       schema1             pageStart
# 43  clariah-tools.ttl  code-lib.ttl       schema1    sourceOrganization
# 44  clariah-tools.ttl  code-lib.ttl       schema1                 email
# 45  clariah-tools.ttl  code-lib.ttl      codemeta     buildInstructions
# 46  clariah-tools.ttl  code-lib.ttl       schema1           downloadUrl
# 47  clariah-tools.ttl  code-lib.ttl       schema1          releaseNotes
# 49  clariah-tools.ttl  code-lib.ttl       schema1              temporal
# 51  clariah-tools.ttl  code-lib.ttl       schema1               license
# 52  clariah-tools.ttl  code-lib.ttl      codemeta                readme
# 53  clariah-tools.ttl  code-lib.ttl       schema1              location
# 54  clariah-tools.ttl  code-lib.ttl       schema1                funder
# 55  clariah-tools.ttl  code-lib.ttl       schema1              isPartOf
# 56  clariah-tools.ttl  code-lib.ttl       schema1               version
# 57  clariah-tools.ttl  code-lib.ttl       schema1   applicationCategory
# 58  clariah-tools.ttl  code-lib.ttl       schema1          audienceType
#
#    Prefix File 2  Property from File 2  Match Score (%) Matched
# 1            dct        isReferencedBy        38.461538      No
# 2            dct               creator        47.619048      No
# 3       codemeta  referencePublication        32.432432      No
# 4            sdo            maintainer        36.363636      No
# 5            dct              requires        57.142857      No
# 6            dct               creator        45.454545      No
# 7            dct               creator        58.823529      No
# 8            dct               creator        66.666667      No
# 9       codemeta  referencePublication        41.176471      No
# 10           sdo                  name        60.000000      No
# 11      codemeta  referencePublication        51.612903      No
# 14           sdo            maintainer        46.153846      No
# 15           sdo            maintainer        60.000000      No
# 16           dct              language        40.000000      No
# 17           sdo            maintainer        44.444444      No
# 18           dct              language        36.363636      No
# 19           dct               creator        46.153846      No
# 20           dct              requires        57.142857      No
# 21           sdo               funding        47.619048      No
# 22           sdo   programmingLanguage        41.176471      No
# 24           dct               creator        54.545455      No
# 25           dct                 title        50.000000      No
# 26           sdo                  name        60.000000      No
# 27           rdf                  type        50.000000      No
# 28           sdo                  name        61.538462      No
# 29      codemeta  referencePublication        52.631579      No
# 30           dct             publisher        63.636364      No
# 31           dct              language        46.153846      No
# 32           dct        isReferencedBy        46.153846      No
# 33           dct               creator        44.444444      No
# 34           sdo               funding        53.333333      No
# 35           sdo                  name        42.857143      No
# 36      codemeta  referencePublication        45.161290      No
# 37           dct               creator        42.857143      No
# 38         sftio          producesData        48.000000      No
# 39           sdo                author        44.444444      No
# 40           dct               creator        55.555556      No
# 41           dct               creator        40.000000      No
# 42           sdo            maintainer        42.105263      No
# 43      codemeta  referencePublication        52.631579      No
# 44           dct                 title        40.000000      No
# 45      codemeta  referencePublication        37.837838      No
# 46           sdo              producer        31.578947      No
# 47           dct               creator        42.105263      No
# 49           sdo                author        42.857143      No
# 51           dct             publisher        50.000000      No
# 52           sdo                  name        60.000000      No
# 53           dct               creator        53.333333      No
# 54           sdo               funding        61.538462      No
# 55           dct             publisher        35.294118      No
# 56           dct              requires        40.000000      No
# 57           sdo            maintainer        48.275862      No
# 58           dct        isReferencedBy        46.153846      No

# %%
# import pandas as pd

# matched_df   = df[df['Matched'] == 'Yes']
# unmatched_df = df[df['Matched'] == 'No']

# matched_df.to_csv('matched_table.csv')
# unmatched_df.to_csv('unmatched_table.csv')
# df.to_csv('df_table.csv')

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

matched_df   = df[df['Matched'] == 'Yes']
unmatched_df = df[df['Matched'] == 'No']

total = len(df)
matched = len(matched_df)
unmatched = len(unmatched_df)

if total > 0:
    matched_pct = (matched / total) * 100
    unmatched_pct = (unmatched / total) * 100
else:
    matched_pct = 0
    unmatched_pct = 0

summary_df = pd.DataFrame({
    "Category": ["Matched", "Unmatched", "Total"],
    "Count": [matched, unmatched, total],
    "Percentage": [f"{matched_pct:.2f}"" %", f"{unmatched_pct:.2f}"" %", "100.00 %"]
})

print("Matching Summary")
display(summary_df)
# Out:
# Matching Summary
#     Category  Count Percentage
# 0    Matched      8    13.11 %
# 1  Unmatched     53    86.89 %
# 2      Total     61   100.00 %
