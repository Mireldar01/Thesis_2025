# %%
import rdflib
from rdflib.namespace import RDF, OWL, RDFS
from rdflib import URIRef, Literal
from rapidfuzz import fuzz, process
# these tools which are taken from the rdflib will help with the handeling of the RDF imports


# what it does it look in the RDF graphs and looks at the extracted entities which havbe rdf types. then what it 
# does is collect the URIs which represent the classes or any defined types in the graph. this will allow to align 
# acros the ontologies by identifing the concepts that help with this.
def extract_entities(graph):
    entities = set()
    for s, p, o in graph.triples((None, RDF.type, None)):
        entities.add(str(s))
    return entities

# this function helps with the readability for the mathcing by cleaning the URIs or literals where they are placed after / and #
# for example like "https://website.com#example" where it will convert it to the "example"
def clean_uri(uri):
    if isinstance(uri, URIRef):
        return str(uri).split("/")[-1].split("#")[-1]
    elif isinstance(uri, Literal):
        return str(uri)
    else:
        return str(uri)

# what this function does is take two lists and finds the most similar list 2 to the list 1 by using the fuzzy method that even works
# when order and form of words are different from each other. after that it will complete will give if matching was successful if the 
# threshold that is set is meet.
def match_labels(labels1, labels2, threshold = 50):
    matches = []
    for label in labels1:
        result = process.extractOne(label, labels2, scorer=fuzz.token_sort_ratio)
        if result is not None:
            match, score, _ = result
            if score >= threshold:
                matches.append((label, match, score))
    return matches

# this function allows to get from the given etities rdfs label values but if they are not found then it will take the clean URIs instead
# because thats the next best thing to use. this method is comfortable if for the alignment you want to use the rdf labels instead of the URI
def get_labels(graph, entity):
    labels = []
    for _, _, label in graph.triples((entity, RDFS.label, None)):
        labels.append(str(label))
    if not labels:
        labels.append(str(entity).split("/")[-1].split("#")[-1])
    return labels

# this will load under the ontology1 the first ontology file in the rdf graph format
ontology1 = rdflib.Graph()
ontology1.parse("clariah-tools.ttl", format="turtle")

# similar as the ontology1 the ontology2 will do the same
ontology2 = rdflib.Graph()
ontology2.parse("code-lib.ttl", format="turtle")

# it will extract the class types from the onotlogy1 and ontology2
classes1 = extract_entities(ontology1)
classes2 = extract_entities(ontology2)

# this will use the function "clean_uri" to make it readable for the matching process
labels1 = [clean_uri(c) for c in classes1]
labels2 = [clean_uri(c) for c in classes2]

# it will match the ontology1 and ontology2
matches = match_labels(labels1, labels2)

# this will print the final matched classes with the paired labels and their scores based on the similarities in the percentages
for l1, l2, score in matches:
    print(f"Matched\n" f"{l1} ↔ {l2}\n" f"with score {score}\n")
# Out:
# Matched
# https://doi.org/10.5281/zenodo.5984171 ↔ https://doi.org/10.5281/zenodo.11225732
# with score 85.71428571428572
#
# Matched
# https://github.com/UtrechtUniversity/ricgraph/blob/main/README.md ↔ https://github.com/UtrechtUniversity/streetview-greenery
# with score 69.42148760330579
#
# Matched
# https://orcid.org/0000-0001-7218-7642 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 54.32098765432099
#
# Matched
# https://iso639-3.sil.org/code/eng ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://docs.rs/stam ↔ https://osf.io/7semh/
# with score 68.29268292682926
#
# Matched
# https://github.com/CLARIAH/grlc/wiki ↔ https://github.com/rivm-syso/DIAPER
# with score 59.154929577464785
#
# Matched
# https://tools.clariah.nl/asr_nl/0.6.2 ↔ https://osf.io/8mw5s/
# with score 51.72413793103448
#
# Matched
# https://doi.org/10.5281/zenodo.3250720 ↔ https://doi.org/10.5281/zenodo.11225732
# with score 90.9090909090909
#
# Matched
# https://orcid.org/0000-0001-9510-0802 ↔ https://doi.org/10.7910/DVN/P39QGO
# with score 53.52112676056338
#
# Matched
# https://doi.org/10.5281/zenodo.4011801 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 86.8421052631579
#
# Matched
# https://iso639-3.sil.org/code/nld ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://orcid.org/0000-0001-5565-7577 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 51.85185185185186
#
# Matched
# https://iso639-3.sil.org/code/por ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://dane.readthedocs.io/en/latest/examples.html ↔ https://osf.io/7semh/
# with score 50.0
#
# Matched
# https://github.com/MartijnBNG ↔ https://github.com/PerlineDemange/CBS-MR
# with score 66.66666666666667
#
# Matched
# https://iso639-3.sil.org/code/swe ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://doi.org/10.5281/zenodo.1482791 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 89.47368421052632
#
# Matched
# https://tools.clariah.nl/auchann/0.2.0 ↔ https://osf.io/gmcjv/
# with score 50.847457627118644
#
# Matched
# http://orcid.org/0009-0006-9941-9582 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 52.5
#
# Matched
# https://iso639-3.sil.org/code/rus ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://dx.doi.org/10.5334/jors.105 ↔ https://doi.org/10.5281/zenodo.11225732
# with score 67.56756756756756
#
# Matched
# https://orcid.org/0000-0001-6854-5646 ↔ https://doi.org/10.34894/63XWJB
# with score 55.88235294117647
#
# Matched
# https://frognlp.readthedocs.io ↔ https://osf.io/46yqp/
# with score 50.98039215686274
#
# Matched
# https://orcid.org/0000-0001-7046-7923 ↔ https://doi.org/10.34894/63XWJB
# with score 58.82352941176471
#
# Matched
# https://tools.clariah.nl/asrservice/0.3 ↔ https://osf.io/7semh/
# with score 53.333333333333336
#
# Matched
# https://foliapy.readthedocs.io/en/latest/ ↔ https://osf.io/xsgdt/
# with score 54.83870967741935
#
# Matched
# https://doi.org/10.5281/zenodo.3944788 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 89.47368421052632
#
# Matched
# https://orcid.org/0000-0002-5145-3603 ↔ https://doi.org/10.34894/63XWJB
# with score 55.88235294117647
#
# Matched
# https://github.com/ETCBC/shebanq/wiki ↔ https://github.com/PerlineDemange/CBS-MR
# with score 59.74025974025974
#
# Matched
# https://doi.org/10.5281/zenodo.2532177 ↔ https://doi.org/10.5281/zenodo.11225732
# with score 90.9090909090909
#
# Matched
# https://tools.clariah.nl/chamd/0.5.12 ↔ https://osf.io/wnhm7/
# with score 55.172413793103445
#
# Matched
# https://orcid.org/0000-0002-1046-0006 ↔ https://doi.org/10.34894/63XWJB
# with score 55.88235294117647
#
# Matched
# https://iso639-3.sil.org/code/ita ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://orcid.org/0000-0002-0301-2029 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 56.790123456790134
#
# Matched
# https://iso639-3.sil.org/code/fry ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# http://folia.readthedocs.io/ ↔ https://osf.io/46yqp/
# with score 53.06122448979591
#
# Matched
# http://dx.doi.org/10.5334/bbi.18 ↔ https://doi.org/10.34894/63XWJB
# with score 66.66666666666667
#
# Matched
# https://tools.clariah.nl/cobalt/snapshot ↔ https://osf.io/7semh/
# with score 52.459016393442624
#
# Matched
# https://pagexml.readthedocs.io/en/latest/ ↔ https://osf.io/xsgdt/
# with score 54.83870967741935
#
# Matched
# https://github.com/jblom ↔ https://github.com/rivm-syso/DIAPER
# with score 67.79661016949152
#
# Matched
# https://orcid.org/0000-0002-2713-213X ↔ https://doi.org/10.34894/63XWJB
# with score 55.88235294117647
#
# Matched
# https://doi.org/10.5281/zenodo.3909515 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 89.47368421052632
#
# Matched
# https://huc.knaw.nl ↔ https://osf.io/wnhm7/
# with score 55.00000000000001
#
# Matched
# https://orcid.org/0000-0003-4646-5842 ↔ https://doi.org/10.34894/63XWJB
# with score 58.82352941176471
#
# Matched
# https://orcid.org/0000-0003-2493-656X ↔ https://doi.org/10.34894/63XWJB
# with score 61.76470588235294
#
# Matched
# https://folia.readthedocs.io/en/latest/ ↔ https://osf.io/xsgdt/
# with score 56.666666666666664
#
# Matched
# https://iso639-3.sil.org/code/deu ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://clam.readthedocs.io ↔ https://osf.io/46yqp/
# with score 54.16666666666667
#
# Matched
# https://iso639-3.sil.org/code/spa ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://doi.org/10.5281/zenodo.5803464 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 86.8421052631579
#
# Matched
# https://tools.clariah.nl/alpinograph/1.0.5 ↔ https://osf.io/wnhm7/
# with score 50.79365079365079
#
# Matched
# https://knaw.nl ↔ https://osf.io/y7tnx/
# with score 55.55555555555556
#
# Matched
# https://github.com/mwigham ↔ https://github.com/rivm-syso/DIAPER
# with score 68.85245901639344
#
# Matched
# https://doi.org/10.5281/zenodo.1007624 ↔ https://doi.org/10.5281/zenodo.11225732
# with score 88.31168831168831
#
# Matched
# https://iso639-3.sil.org/code/tur ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://tools.clariah.nl/cesar/unknown ↔ https://osf.io/8mw5s/
# with score 50.847457627118644
#
# Matched
# https://iso639-3.sil.org/code/fra ↔ https://osf.io/gmcjv/
# with score 55.55555555555556
#
# Matched
# https://doi.org/10.1163/24523666-01000011 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 68.23529411764706
#
# Matched
# https://dig.hum.uu.nl ↔ https://osf.io/gmcjv/
# with score 52.38095238095239
#
# Matched
# http://textrepo.readthedocs.io/en/latest/ ↔ https://osf.io/xsgdt/
# with score 51.61290322580645
#
# Matched
# https://tools.clariah.nl/api ↔ https://osf.io/46yqp/
# with score 57.14285714285714
#
# Matched
# https://doi.org/10.5281/zenodo.3909507 ↔ https://doi.org/10.5281/zenodo.7443895
# with score 89.47368421052632
#
# Matched
# https://github.com/MartenPostma/OpenDutchWordnet/raw/master/odwn_documentation.pdf ↔ https://github.com/MarkDVerhagen/Dutch_healthcare_inequalities_COVID19
# with score 52.63157894736843
#
# Matched
# https://orcid.org/0000-0002-3755-5929 ↔ https://doi.org/10.1016/j.lanepe.2023.100749
# with score 54.32098765432099
#
# Matched
# https://tools.clariah.nl/alud/2.14.0 ↔ https://osf.io/xsgdt/
# with score 52.63157894736843

# %%
import pandas as pd


threshold = 50
rows = []

for label1 in labels1:
    
    res = process.extractOne(label1, labels2, scorer=fuzz.token_sort_ratio)
    if res:
        label2, score, _ = res
    else:
        label2, score = "—", 0

    rows.append({
        "File 1": "clariah-tools.ttl",
        "File 2": "code-lib.ttl" if label2 != "—" else "",
        "Entity from File 1": label1,
        "Entity from File 2": label2,
        "Match Score (%)": score,
        "Matched": "Yes" if score >= threshold else "No"
    })

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.DataFrame(rows)

df
# Out:
#                 File 1        File 2  \
# 0    clariah-tools.ttl  code-lib.ttl
# 1    clariah-tools.ttl  code-lib.ttl
# 2    clariah-tools.ttl  code-lib.ttl
# 3    clariah-tools.ttl  code-lib.ttl
# 4    clariah-tools.ttl  code-lib.ttl
# 5    clariah-tools.ttl  code-lib.ttl
# 6    clariah-tools.ttl  code-lib.ttl
# 7    clariah-tools.ttl  code-lib.ttl
# 8    clariah-tools.ttl  code-lib.ttl
# 9    clariah-tools.ttl  code-lib.ttl
# 10   clariah-tools.ttl  code-lib.ttl
# 11   clariah-tools.ttl  code-lib.ttl
# 12   clariah-tools.ttl  code-lib.ttl
# 13   clariah-tools.ttl  code-lib.ttl
# 14   clariah-tools.ttl  code-lib.ttl
# 15   clariah-tools.ttl  code-lib.ttl
# 16   clariah-tools.ttl  code-lib.ttl
# 17   clariah-tools.ttl  code-lib.ttl
# 18   clariah-tools.ttl  code-lib.ttl
# 19   clariah-tools.ttl  code-lib.ttl
# 20   clariah-tools.ttl  code-lib.ttl
# 21   clariah-tools.ttl  code-lib.ttl
# 22   clariah-tools.ttl  code-lib.ttl
# 23   clariah-tools.ttl  code-lib.ttl
# 24   clariah-tools.ttl  code-lib.ttl
# 25   clariah-tools.ttl  code-lib.ttl
# 26   clariah-tools.ttl  code-lib.ttl
# 27   clariah-tools.ttl  code-lib.ttl
# 28   clariah-tools.ttl  code-lib.ttl
# 29   clariah-tools.ttl  code-lib.ttl
# 30   clariah-tools.ttl  code-lib.ttl
# 31   clariah-tools.ttl  code-lib.ttl
# 32   clariah-tools.ttl  code-lib.ttl
# 33   clariah-tools.ttl  code-lib.ttl
# 34   clariah-tools.ttl  code-lib.ttl
# 35   clariah-tools.ttl  code-lib.ttl
# 36   clariah-tools.ttl  code-lib.ttl
# 37   clariah-tools.ttl  code-lib.ttl
# 38   clariah-tools.ttl  code-lib.ttl
# 39   clariah-tools.ttl  code-lib.ttl
# 40   clariah-tools.ttl  code-lib.ttl
# 41   clariah-tools.ttl  code-lib.ttl
# 42   clariah-tools.ttl  code-lib.ttl
# 43   clariah-tools.ttl  code-lib.ttl
# 44   clariah-tools.ttl  code-lib.ttl
# 45   clariah-tools.ttl  code-lib.ttl
# 46   clariah-tools.ttl  code-lib.ttl
# 47   clariah-tools.ttl  code-lib.ttl
# 48   clariah-tools.ttl  code-lib.ttl
# 49   clariah-tools.ttl  code-lib.ttl
# 50   clariah-tools.ttl  code-lib.ttl
# 51   clariah-tools.ttl  code-lib.ttl
# 52   clariah-tools.ttl  code-lib.ttl
# 53   clariah-tools.ttl  code-lib.ttl
# 54   clariah-tools.ttl  code-lib.ttl
# 55   clariah-tools.ttl  code-lib.ttl
# 56   clariah-tools.ttl  code-lib.ttl
# 57   clariah-tools.ttl  code-lib.ttl
# 58   clariah-tools.ttl  code-lib.ttl
# 59   clariah-tools.ttl  code-lib.ttl
# 60   clariah-tools.ttl  code-lib.ttl
# 61   clariah-tools.ttl  code-lib.ttl
# 62   clariah-tools.ttl  code-lib.ttl
# 63   clariah-tools.ttl  code-lib.ttl
# 64   clariah-tools.ttl  code-lib.ttl
# 65   clariah-tools.ttl  code-lib.ttl
# 66   clariah-tools.ttl  code-lib.ttl
# 67   clariah-tools.ttl  code-lib.ttl
# 68   clariah-tools.ttl  code-lib.ttl
# 69   clariah-tools.ttl  code-lib.ttl
# 70   clariah-tools.ttl  code-lib.ttl
# 71   clariah-tools.ttl  code-lib.ttl
# 72   clariah-tools.ttl  code-lib.ttl
# 73   clariah-tools.ttl  code-lib.ttl
# 74   clariah-tools.ttl  code-lib.ttl
# 75   clariah-tools.ttl  code-lib.ttl
# 76   clariah-tools.ttl  code-lib.ttl
# 77   clariah-tools.ttl  code-lib.ttl
# 78   clariah-tools.ttl  code-lib.ttl
# 79   clariah-tools.ttl  code-lib.ttl
# 80   clariah-tools.ttl  code-lib.ttl
# 81   clariah-tools.ttl  code-lib.ttl
# 82   clariah-tools.ttl  code-lib.ttl
# 83   clariah-tools.ttl  code-lib.ttl
# 84   clariah-tools.ttl  code-lib.ttl
# 85   clariah-tools.ttl  code-lib.ttl
# 86   clariah-tools.ttl  code-lib.ttl
# 87   clariah-tools.ttl  code-lib.ttl
# 88   clariah-tools.ttl  code-lib.ttl
# 89   clariah-tools.ttl  code-lib.ttl
# 90   clariah-tools.ttl  code-lib.ttl
# 91   clariah-tools.ttl  code-lib.ttl
# 92   clariah-tools.ttl  code-lib.ttl
# 93   clariah-tools.ttl  code-lib.ttl
# 94   clariah-tools.ttl  code-lib.ttl
# 95   clariah-tools.ttl  code-lib.ttl
# 96   clariah-tools.ttl  code-lib.ttl
# 97   clariah-tools.ttl  code-lib.ttl
# 98   clariah-tools.ttl  code-lib.ttl
# 99   clariah-tools.ttl  code-lib.ttl
# 100  clariah-tools.ttl  code-lib.ttl
# 101  clariah-tools.ttl  code-lib.ttl
# 102  clariah-tools.ttl  code-lib.ttl
# 103  clariah-tools.ttl  code-lib.ttl
# 104  clariah-tools.ttl  code-lib.ttl
# 105  clariah-tools.ttl  code-lib.ttl
# 106  clariah-tools.ttl  code-lib.ttl
# 107  clariah-tools.ttl  code-lib.ttl
# 108  clariah-tools.ttl  code-lib.ttl
# 109  clariah-tools.ttl  code-lib.ttl
# 110  clariah-tools.ttl  code-lib.ttl
# 111  clariah-tools.ttl  code-lib.ttl
# 112  clariah-tools.ttl  code-lib.ttl
# 113  clariah-tools.ttl  code-lib.ttl
# 114  clariah-tools.ttl  code-lib.ttl
# 115  clariah-tools.ttl  code-lib.ttl
# 116  clariah-tools.ttl  code-lib.ttl
# 117  clariah-tools.ttl  code-lib.ttl
# 118  clariah-tools.ttl  code-lib.ttl
# 119  clariah-tools.ttl  code-lib.ttl
# 120  clariah-tools.ttl  code-lib.ttl
# 121  clariah-tools.ttl  code-lib.ttl
# 122  clariah-tools.ttl  code-lib.ttl
# 123  clariah-tools.ttl  code-lib.ttl
# 124  clariah-tools.ttl  code-lib.ttl
# 125  clariah-tools.ttl  code-lib.ttl
# 126  clariah-tools.ttl  code-lib.ttl
# 127  clariah-tools.ttl  code-lib.ttl
# 128  clariah-tools.ttl  code-lib.ttl
# 129  clariah-tools.ttl  code-lib.ttl
# 130  clariah-tools.ttl  code-lib.ttl
# 131  clariah-tools.ttl  code-lib.ttl
# 132  clariah-tools.ttl  code-lib.ttl
# 133  clariah-tools.ttl  code-lib.ttl
# 134  clariah-tools.ttl  code-lib.ttl
# 135  clariah-tools.ttl  code-lib.ttl
# 136  clariah-tools.ttl  code-lib.ttl
# 137  clariah-tools.ttl  code-lib.ttl
# 138  clariah-tools.ttl  code-lib.ttl
# 139  clariah-tools.ttl  code-lib.ttl
# 140  clariah-tools.ttl  code-lib.ttl
# 141  clariah-tools.ttl  code-lib.ttl
# 142  clariah-tools.ttl  code-lib.ttl
# 143  clariah-tools.ttl  code-lib.ttl
# 144  clariah-tools.ttl  code-lib.ttl
# 145  clariah-tools.ttl  code-lib.ttl
# 146  clariah-tools.ttl  code-lib.ttl
# 147  clariah-tools.ttl  code-lib.ttl
# 148  clariah-tools.ttl  code-lib.ttl
# 149  clariah-tools.ttl  code-lib.ttl
#
#                                     Entity from File 1  \
# 0               https://doi.org/10.5281/zenodo.5984171
# 1    https://github.com/UtrechtUniversity/ricgraph/...
# 2    https://tools.clariah.nl/commandlineapplicatio...
# 3                https://orcid.org/0000-0001-7218-7642
# 4    https://annorepo-python-client.readthedocs.io/...
# 5                    https://iso639-3.sil.org/code/eng
# 6    https://tools.clariah.nl/commandlineapplicatio...
# 7    https://tools.clariah.nl/commandlineapplicatio...
# 8                                 https://docs.rs/stam
# 9    https://tools.clariah.nl/commandlineapplicatio...
# 10   https://tools.clariah.nl/commandlineapplicatio...
# 11    https://folia.readthedocs.io/en/latest/form.html
# 12   https://tools.clariah.nl/commandlineapplicatio...
# 13   https://tools.clariah.nl/commandlineapplicatio...
# 14   https://tools.clariah.nl/commandlineapplicatio...
# 15       https://tools.clariah.nl/alpino-service/2.4.1
# 16   https://tools.clariah.nl/commandlineapplicatio...
# 17      https://tools.clariah.nl/annorepo-client/0.1.3
# 18                https://github.com/CLARIAH/grlc/wiki
# 19   https://tools.clariah.nl/commandlineapplicatio...
# 20               https://tools.clariah.nl/asr_nl/0.6.2
# 21              https://doi.org/10.5281/zenodo.3250720
# 22               https://orcid.org/0000-0001-9510-0802
# 23              https://doi.org/10.5281/zenodo.4011801
# 24                   https://iso639-3.sil.org/code/nld
# 25               https://orcid.org/0000-0001-5565-7577
# 26        https://tools.clariah.nl/audience/developers
# 27   https://tools.clariah.nl/commandlineapplicatio...
# 28                   https://iso639-3.sil.org/code/por
# 29   https://tools.clariah.nl/commandlineapplicatio...
# 30         https://mediasuite.clariah.nl/documentation
# 31   https://tools.clariah.nl/commandlineapplicatio...
# 32   http://flat.readthedocs.io/en/latest/installat...
# 33   https://dane.readthedocs.io/en/latest/examples...
# 34   https://tools.clariah.nl/commandlineapplicatio...
# 35                       https://github.com/MartijnBNG
# 36   https://tools.clariah.nl/commandlineapplicatio...
# 37                   https://iso639-3.sil.org/code/swe
# 38              https://doi.org/10.5281/zenodo.1482791
# 39   http://www.sketchengine.co.uk/documentation/wi...
# 40              https://tools.clariah.nl/auchann/0.2.0
# 41          https://tools.clariah.nl/audience/religion
# 42                http://orcid.org/0009-0006-9941-9582
# 43   https://tools.clariah.nl/commandlineapplicatio...
# 44   https://tools.clariah.nl/commandlineapplicatio...
# 45   https://tools.clariah.nl/commandlineapplicatio...
# 46   https://github.com/CLARIAH/wp6-missieven/blob/...
# 47   https://pagexml.readthedocs.io/en/latest/?badg...
# 48     http://csvw-converter.readthedocs.io/en/latest/
# 49   http://flat.readthedocs.io/en/latest/user_guid...
# 50                   https://iso639-3.sil.org/code/rus
# 51                 https://dx.doi.org/10.5334/jors.105
# 52   https://tools.clariah.nl/commandlineapplicatio...
# 53               https://orcid.org/0000-0001-6854-5646
# 54   https://annorepo-python-client.readthedocs.io/...
# 55   https://nbviewer.org/github/CLARIAH/wp6-missie...
# 56                      https://frognlp.readthedocs.io
# 57   https://datasetregister.netwerkdigitaalerfgoed...
# 58               https://orcid.org/0000-0001-7046-7923
# 59         https://tools.clariah.nl/audience/education
# 60   https://identifier.overheid.nl/tooi/id/ministe...
# 61             https://tools.clariah.nl/asrservice/0.3
# 62   http://flat.readthedocs.io/en/latest/administr...
# 63           https://foliapy.readthedocs.io/en/latest/
# 64              https://doi.org/10.5281/zenodo.3944788
# 65   https://tools.clariah.nl/commandlineapplicatio...
# 66   https://tools.clariah.nl/commandlineapplicatio...
# 67   https://tools.clariah.nl/commandlineapplicatio...
# 68               https://orcid.org/0000-0002-5145-3603
# 69   https://tools.clariah.nl/commandlineapplicatio...
# 70   https://annotation.github.io/text-fabric/tf/in...
# 71               https://github.com/ETCBC/shebanq/wiki
# 72              https://doi.org/10.5281/zenodo.2532177
# 73               https://tools.clariah.nl/chamd/0.5.12
# 74               https://orcid.org/0000-0002-1046-0006
# 75                   https://iso639-3.sil.org/code/ita
# 76               https://orcid.org/0000-0002-0301-2029
# 77   https://tools.clariah.nl/commandlineapplicatio...
# 78   https://tools.clariah.nl/commandlineapplicatio...
# 79                   https://iso639-3.sil.org/code/fry
# 80   https://tools.clariah.nl/commandlineapplicatio...
# 81   https://tools.clariah.nl/commandlineapplicatio...
# 82                        http://folia.readthedocs.io/
# 83   https://tools.clariah.nl/clariah-fcs-endpoints...
# 84   https://nbviewer.org/github/annotation/banks/b...
# 85   https://tools.clariah.nl/audience/science-rese...
# 86   https://tools.clariah.nl/commandlineapplicatio...
# 87   https://knaw-huc.github.io/annorepo/docs/api-u...
# 88                    http://dx.doi.org/10.5334/bbi.18
# 89            https://tools.clariah.nl/cobalt/snapshot
# 90   https://tools.clariah.nl/commandlineapplicatio...
# 91           https://pagexml.readthedocs.io/en/latest/
# 92   https://tools.clariah.nl/commandlineapplicatio...
# 93                   http://hdl.handle.net/2066/131547
# 94   https://tools.clariah.nl/commandlineapplicatio...
# 95                            https://github.com/jblom
# 96               https://orcid.org/0000-0002-2713-213X
# 97              https://doi.org/10.5281/zenodo.3909515
# 98   https://tools.clariah.nl/commandlineapplicatio...
# 99                                 https://huc.knaw.nl
# 100  https://tools.clariah.nl/commandlineapplicatio...
# 101  https://tools.clariah.nl/commandlineapplicatio...
# 102  https://nbviewer.org/github/Nino-cunei/uruk/bl...
# 103              https://orcid.org/0000-0003-4646-5842
# 104              https://orcid.org/0000-0003-2493-656X
# 105                  http://hdl.handle.net/2066/134833
# 106  https://tools.clariah.nl/commandlineapplicatio...
# 107  https://tools.clariah.nl/commandlineapplicatio...
# 108            https://folia.readthedocs.io/en/latest/
# 109  https://dane.readthedocs.io/en/latest/intro.ht...
# 110       https://portal.clarin.ivdnt.org/galahad/help
# 111                  https://iso639-3.sil.org/code/deu
# 112  https://nbviewer.org/github/ETCBC/bhsa/blob/ma...
# 113  https://tools.clariah.nl/commandlineapplicatio...
# 114  https://tools.clariah.nl/commandlineapplicatio...
# 115  https://tools.clariah.nl/commandlineapplicatio...
# 116  http://flat.readthedocs.io/en/latest/?badge=la...
# 117  https://tools.clariah.nl/commandlineapplicatio...
# 118  https://datasetregister.netwerkdigitaalerfgoed...
# 119                        https://clam.readthedocs.io
# 120                  https://iso639-3.sil.org/code/spa
# 121             https://doi.org/10.5281/zenodo.5803464
# 122  https://tools.clariah.nl/commandlineapplicatio...
# 123  https://tools.clariah.nl/commandlineapplicatio...
# 124         https://tools.clariah.nl/alpinograph/1.0.5
# 125  https://nbviewer.org/github/Nino-cunei/oldbaby...
# 126                                    https://knaw.nl
# 127  http://www.w3.org/2004/02/skos/core#ConceptScheme
# 128  https://tools.clariah.nl/commandlineapplicatio...
# 129                         https://github.com/mwigham
# 130             https://doi.org/10.5281/zenodo.1007624
# 131        http://www.w3.org/2004/02/skos/core#Concept
# 132                  https://iso639-3.sil.org/code/tur
# 133             https://tools.clariah.nl/cesar/unknown
# 134                  https://iso639-3.sil.org/code/fra
# 135  https://tools.clariah.nl/commandlineapplicatio...
# 136  https://tools.clariah.nl/commandlineapplicatio...
# 137  https://tools.clariah.nl/commandlineapplicatio...
# 138  https://kg.odissei.nl/.well-known/genid/8d5460...
# 139          https://doi.org/10.1163/24523666-01000011
# 140                              https://dig.hum.uu.nl
# 141  https://tools.clariah.nl/commandlineapplicatio...
# 142          http://textrepo.readthedocs.io/en/latest/
# 143                       https://tools.clariah.nl/api
# 144             https://doi.org/10.5281/zenodo.3909507
# 145      https://tools.clariah.nl/audience/researchers
# 146  https://github.com/MartenPostma/OpenDutchWordn...
# 147              https://orcid.org/0000-0002-3755-5929
# 29       No
# 30       No
# 31       No
# 32       No
# 33      Yes
# 34       No
# 35      Yes
# 36       No
# 37      Yes
# 38      Yes
# 39       No
# 40      Yes
# 41       No
# 42      Yes
# 43       No
# 44       No
# 45       No
# 46       No
# 47       No
# 48       No
# 49       No
# 50      Yes
# 51      Yes
# 52       No
# 53      Yes
# 54       No
# 55       No
# 56      Yes
# 57       No
# 58      Yes
# 59       No
# 60       No
# 61      Yes
# 62       No
# 63      Yes
# 64      Yes
# 65       No
# 66       No
# 67       No
# 68      Yes
# 69       No
# 70       No
# 71      Yes
# 72      Yes
# 73      Yes
# 74      Yes
# 75      Yes
# 76      Yes
# 77       No
# 78       No
# 79      Yes
# 80       No
# 81       No
# 82      Yes
# 83       No
# 84       No
# 85       No
# 86       No
# 87       No
# 88      Yes
# 89      Yes
# 90       No
# 91      Yes
# 92       No
# 93       No
# 94       No
# 95      Yes
# 96      Yes
# 97      Yes
# 98       No
# 99      Yes
# 100      No
# 101      No
# 102      No
# 103     Yes
# 104     Yes
# 105      No
# 106      No
# 107      No
# 108     Yes
# 109      No
# 110      No
# 111     Yes
# 112      No
# 113      No
# 114      No
# 115      No
# 116      No
# 117      No
# 118      No
# 119     Yes
# 120     Yes
# 121     Yes
# 122      No
# 123      No
# 124     Yes
# 125      No
# 126     Yes
# 127      No
# 128      No
# 129     Yes
# 130     Yes
# 131      No
# 132     Yes
# 133     Yes
# 134     Yes
# 135      No
# 136      No
# 137      No
# 138      No
# 139     Yes
# 140     Yes
# 141      No
# 142     Yes
# 143     Yes
# 144     Yes
# 145      No
# 146     Yes
# 147     Yes
# 148      No
# 149     Yes

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

matched_df   = df[df['Matched'] == 'Yes']
unmatched_df = df[df['Matched'] == 'No']

print("Matched Entities")
display(matched_df)

print("Unmatched Entities")
display(unmatched_df)
# Out:
# Matched Entities
#                 File 1        File 2  \
# 0    clariah-tools.ttl  code-lib.ttl
# 1    clariah-tools.ttl  code-lib.ttl
# 3    clariah-tools.ttl  code-lib.ttl
# 5    clariah-tools.ttl  code-lib.ttl
# 8    clariah-tools.ttl  code-lib.ttl
# 18   clariah-tools.ttl  code-lib.ttl
# 20   clariah-tools.ttl  code-lib.ttl
# 21   clariah-tools.ttl  code-lib.ttl
# 22   clariah-tools.ttl  code-lib.ttl
# 23   clariah-tools.ttl  code-lib.ttl
# 24   clariah-tools.ttl  code-lib.ttl
# 25   clariah-tools.ttl  code-lib.ttl
# 28   clariah-tools.ttl  code-lib.ttl
# 33   clariah-tools.ttl  code-lib.ttl
# 35   clariah-tools.ttl  code-lib.ttl
# 37   clariah-tools.ttl  code-lib.ttl
# 38   clariah-tools.ttl  code-lib.ttl
# 40   clariah-tools.ttl  code-lib.ttl
# 42   clariah-tools.ttl  code-lib.ttl
# 50   clariah-tools.ttl  code-lib.ttl
# 51   clariah-tools.ttl  code-lib.ttl
# 53   clariah-tools.ttl  code-lib.ttl
# 56   clariah-tools.ttl  code-lib.ttl
# 58   clariah-tools.ttl  code-lib.ttl
# 61   clariah-tools.ttl  code-lib.ttl
# 63   clariah-tools.ttl  code-lib.ttl
# 64   clariah-tools.ttl  code-lib.ttl
# 68   clariah-tools.ttl  code-lib.ttl
# 71   clariah-tools.ttl  code-lib.ttl
# 72   clariah-tools.ttl  code-lib.ttl
# 73   clariah-tools.ttl  code-lib.ttl
# 74   clariah-tools.ttl  code-lib.ttl
# 75   clariah-tools.ttl  code-lib.ttl
# 76   clariah-tools.ttl  code-lib.ttl
# 79   clariah-tools.ttl  code-lib.ttl
# 82   clariah-tools.ttl  code-lib.ttl
# 88   clariah-tools.ttl  code-lib.ttl
# 89   clariah-tools.ttl  code-lib.ttl
# 91   clariah-tools.ttl  code-lib.ttl
# 95   clariah-tools.ttl  code-lib.ttl
# 96   clariah-tools.ttl  code-lib.ttl
# 97   clariah-tools.ttl  code-lib.ttl
# 99   clariah-tools.ttl  code-lib.ttl
# 103  clariah-tools.ttl  code-lib.ttl
# 104  clariah-tools.ttl  code-lib.ttl
# 108  clariah-tools.ttl  code-lib.ttl
# 111  clariah-tools.ttl  code-lib.ttl
# 119  clariah-tools.ttl  code-lib.ttl
# 120  clariah-tools.ttl  code-lib.ttl
# 121  clariah-tools.ttl  code-lib.ttl
# 124  clariah-tools.ttl  code-lib.ttl
# 126  clariah-tools.ttl  code-lib.ttl
# 129  clariah-tools.ttl  code-lib.ttl
# 130  clariah-tools.ttl  code-lib.ttl
# 132  clariah-tools.ttl  code-lib.ttl
# 133  clariah-tools.ttl  code-lib.ttl
# 134  clariah-tools.ttl  code-lib.ttl
# 139  clariah-tools.ttl  code-lib.ttl
# 140  clariah-tools.ttl  code-lib.ttl
# 142  clariah-tools.ttl  code-lib.ttl
# 143  clariah-tools.ttl  code-lib.ttl
# 144  clariah-tools.ttl  code-lib.ttl
# 146  clariah-tools.ttl  code-lib.ttl
# 147  clariah-tools.ttl  code-lib.ttl
# 149  clariah-tools.ttl  code-lib.ttl
#
#                                     Entity from File 1  \
# 0               https://doi.org/10.5281/zenodo.5984171
# 1    https://github.com/UtrechtUniversity/ricgraph/...
# 3                https://orcid.org/0000-0001-7218-7642
# 5                    https://iso639-3.sil.org/code/eng
# 8                                 https://docs.rs/stam
# 18                https://github.com/CLARIAH/grlc/wiki
# 20               https://tools.clariah.nl/asr_nl/0.6.2
# 21              https://doi.org/10.5281/zenodo.3250720
# 22               https://orcid.org/0000-0001-9510-0802
# 23              https://doi.org/10.5281/zenodo.4011801
# 24                   https://iso639-3.sil.org/code/nld
# 25               https://orcid.org/0000-0001-5565-7577
# 28                   https://iso639-3.sil.org/code/por
# 33   https://dane.readthedocs.io/en/latest/examples...
# 35                       https://github.com/MartijnBNG
# 37                   https://iso639-3.sil.org/code/swe
# 38              https://doi.org/10.5281/zenodo.1482791
# 40              https://tools.clariah.nl/auchann/0.2.0
# 42                http://orcid.org/0009-0006-9941-9582
# 50                   https://iso639-3.sil.org/code/rus
# 51                 https://dx.doi.org/10.5334/jors.105
# 53               https://orcid.org/0000-0001-6854-5646
# 56                      https://frognlp.readthedocs.io
# 58               https://orcid.org/0000-0001-7046-7923
# 61             https://tools.clariah.nl/asrservice/0.3
# 63           https://foliapy.readthedocs.io/en/latest/
# 64              https://doi.org/10.5281/zenodo.3944788
# 68               https://orcid.org/0000-0002-5145-3603
# 71               https://github.com/ETCBC/shebanq/wiki
# 72              https://doi.org/10.5281/zenodo.2532177
# 73               https://tools.clariah.nl/chamd/0.5.12
# 74               https://orcid.org/0000-0002-1046-0006
# 75                   https://iso639-3.sil.org/code/ita
# 76               https://orcid.org/0000-0002-0301-2029
# 79                   https://iso639-3.sil.org/code/fry
# 82                        http://folia.readthedocs.io/
# 88                    http://dx.doi.org/10.5334/bbi.18
# 89            https://tools.clariah.nl/cobalt/snapshot
# 91           https://pagexml.readthedocs.io/en/latest/
# 95                            https://github.com/jblom
# 96               https://orcid.org/0000-0002-2713-213X
# 97              https://doi.org/10.5281/zenodo.3909515
# 99                                 https://huc.knaw.nl
# 103              https://orcid.org/0000-0003-4646-5842
# 104              https://orcid.org/0000-0003-2493-656X
# 108            https://folia.readthedocs.io/en/latest/
# 111                  https://iso639-3.sil.org/code/deu
# 119                        https://clam.readthedocs.io
# 120                  https://iso639-3.sil.org/code/spa
# 121             https://doi.org/10.5281/zenodo.5803464
# 124         https://tools.clariah.nl/alpinograph/1.0.5
# 126                                    https://knaw.nl
# 129                         https://github.com/mwigham
# 130             https://doi.org/10.5281/zenodo.1007624
# 132                  https://iso639-3.sil.org/code/tur
# 133             https://tools.clariah.nl/cesar/unknown
# 134                  https://iso639-3.sil.org/code/fra
# 139          https://doi.org/10.1163/24523666-01000011
# 140                              https://dig.hum.uu.nl
# 142          http://textrepo.readthedocs.io/en/latest/
# 143                       https://tools.clariah.nl/api
# 144             https://doi.org/10.5281/zenodo.3909507
# 146  https://github.com/MartenPostma/OpenDutchWordn...
# 147              https://orcid.org/0000-0002-3755-5929
# 149               https://tools.clariah.nl/alud/2.14.0
#
#                                     Entity from File 2  Match Score (%)  \
# 0              https://doi.org/10.5281/zenodo.11225732        85.714286
# 1    https://github.com/UtrechtUniversity/streetvie...        69.421488
# 3         https://doi.org/10.1016/j.lanepe.2023.100749        54.320988
# 5                                https://osf.io/gmcjv/        55.555556
# 8                                https://osf.io/7semh/        68.292683
# 18                 https://github.com/rivm-syso/DIAPER        59.154930
# 20                               https://osf.io/8mw5s/        51.724138
# 21             https://doi.org/10.5281/zenodo.11225732        90.909091
# 22                  https://doi.org/10.7910/DVN/P39QGO        53.521127
# 23              https://doi.org/10.5281/zenodo.7443895        86.842105
# 24                               https://osf.io/gmcjv/        55.555556
# 25        https://doi.org/10.1016/j.lanepe.2023.100749        51.851852
# 28                               https://osf.io/gmcjv/        55.555556
# 33                               https://osf.io/7semh/        50.000000
# 35            https://github.com/PerlineDemange/CBS-MR        66.666667
# 37                               https://osf.io/gmcjv/        55.555556
# 38              https://doi.org/10.5281/zenodo.7443895        89.473684
# 40                               https://osf.io/gmcjv/        50.847458
# 42        https://doi.org/10.1016/j.lanepe.2023.100749        52.500000
# 50                               https://osf.io/gmcjv/        55.555556
# 97      Yes
# 99      Yes
# 103     Yes
# 104     Yes
# 108     Yes
# 111     Yes
# 119     Yes
# 120     Yes
# 121     Yes
# 124     Yes
# 126     Yes
# 129     Yes
# 130     Yes
# 132     Yes
# 133     Yes
# 134     Yes
# 139     Yes
# 140     Yes
# 142     Yes
# 143     Yes
# 144     Yes
# 146     Yes
# 147     Yes
# 149     Yes
# Unmatched Entities
#                 File 1        File 2  \
# 2    clariah-tools.ttl  code-lib.ttl
# 4    clariah-tools.ttl  code-lib.ttl
# 6    clariah-tools.ttl  code-lib.ttl
# 7    clariah-tools.ttl  code-lib.ttl
# 9    clariah-tools.ttl  code-lib.ttl
# 10   clariah-tools.ttl  code-lib.ttl
# 11   clariah-tools.ttl  code-lib.ttl
# 12   clariah-tools.ttl  code-lib.ttl
# 13   clariah-tools.ttl  code-lib.ttl
# 14   clariah-tools.ttl  code-lib.ttl
# 15   clariah-tools.ttl  code-lib.ttl
# 16   clariah-tools.ttl  code-lib.ttl
# 17   clariah-tools.ttl  code-lib.ttl
# 19   clariah-tools.ttl  code-lib.ttl
# 26   clariah-tools.ttl  code-lib.ttl
# 27   clariah-tools.ttl  code-lib.ttl
# 29   clariah-tools.ttl  code-lib.ttl
# 30   clariah-tools.ttl  code-lib.ttl
# 31   clariah-tools.ttl  code-lib.ttl
# 32   clariah-tools.ttl  code-lib.ttl
# 34   clariah-tools.ttl  code-lib.ttl
# 36   clariah-tools.ttl  code-lib.ttl
# 39   clariah-tools.ttl  code-lib.ttl
# 41   clariah-tools.ttl  code-lib.ttl
# 43   clariah-tools.ttl  code-lib.ttl
# 44   clariah-tools.ttl  code-lib.ttl
# 45   clariah-tools.ttl  code-lib.ttl
# 46   clariah-tools.ttl  code-lib.ttl
# 47   clariah-tools.ttl  code-lib.ttl
# 48   clariah-tools.ttl  code-lib.ttl
# 49   clariah-tools.ttl  code-lib.ttl
# 52   clariah-tools.ttl  code-lib.ttl
# 54   clariah-tools.ttl  code-lib.ttl
# 55   clariah-tools.ttl  code-lib.ttl
# 57   clariah-tools.ttl  code-lib.ttl
# 59   clariah-tools.ttl  code-lib.ttl
# 60   clariah-tools.ttl  code-lib.ttl
# 62   clariah-tools.ttl  code-lib.ttl
# 65   clariah-tools.ttl  code-lib.ttl
# 66   clariah-tools.ttl  code-lib.ttl
# 67   clariah-tools.ttl  code-lib.ttl
# 69   clariah-tools.ttl  code-lib.ttl
# 70   clariah-tools.ttl  code-lib.ttl
# 77   clariah-tools.ttl  code-lib.ttl
# 78   clariah-tools.ttl  code-lib.ttl
# 80   clariah-tools.ttl  code-lib.ttl
# 81   clariah-tools.ttl  code-lib.ttl
# 83   clariah-tools.ttl  code-lib.ttl
# 84   clariah-tools.ttl  code-lib.ttl
# 85   clariah-tools.ttl  code-lib.ttl
# 86   clariah-tools.ttl  code-lib.ttl
# 87   clariah-tools.ttl  code-lib.ttl
# 90   clariah-tools.ttl  code-lib.ttl
# 92   clariah-tools.ttl  code-lib.ttl
# 93   clariah-tools.ttl  code-lib.ttl
# 94   clariah-tools.ttl  code-lib.ttl
# 98   clariah-tools.ttl  code-lib.ttl
# 100  clariah-tools.ttl  code-lib.ttl
# 101  clariah-tools.ttl  code-lib.ttl
# 102  clariah-tools.ttl  code-lib.ttl
# 105  clariah-tools.ttl  code-lib.ttl
# 106  clariah-tools.ttl  code-lib.ttl
# 107  clariah-tools.ttl  code-lib.ttl
# 109  clariah-tools.ttl  code-lib.ttl
# 110  clariah-tools.ttl  code-lib.ttl
# 112  clariah-tools.ttl  code-lib.ttl
# 113  clariah-tools.ttl  code-lib.ttl
# 114  clariah-tools.ttl  code-lib.ttl
# 115  clariah-tools.ttl  code-lib.ttl
# 116  clariah-tools.ttl  code-lib.ttl
# 117  clariah-tools.ttl  code-lib.ttl
# 118  clariah-tools.ttl  code-lib.ttl
# 122  clariah-tools.ttl  code-lib.ttl
# 123  clariah-tools.ttl  code-lib.ttl
# 125  clariah-tools.ttl  code-lib.ttl
# 127  clariah-tools.ttl  code-lib.ttl
# 128  clariah-tools.ttl  code-lib.ttl
# 131  clariah-tools.ttl  code-lib.ttl
# 135  clariah-tools.ttl  code-lib.ttl
# 136  clariah-tools.ttl  code-lib.ttl
# 137  clariah-tools.ttl  code-lib.ttl
# 138  clariah-tools.ttl  code-lib.ttl
# 141  clariah-tools.ttl  code-lib.ttl
# 145  clariah-tools.ttl  code-lib.ttl
# 148  clariah-tools.ttl  code-lib.ttl
#
#                                     Entity from File 1  \
# 2    https://tools.clariah.nl/commandlineapplicatio...
# 4    https://annorepo-python-client.readthedocs.io/...
# 6    https://tools.clariah.nl/commandlineapplicatio...
# 7    https://tools.clariah.nl/commandlineapplicatio...
# 9    https://tools.clariah.nl/commandlineapplicatio...
# 10   https://tools.clariah.nl/commandlineapplicatio...
# 11    https://folia.readthedocs.io/en/latest/form.html
# 12   https://tools.clariah.nl/commandlineapplicatio...
# 13   https://tools.clariah.nl/commandlineapplicatio...
# 14   https://tools.clariah.nl/commandlineapplicatio...
# 15       https://tools.clariah.nl/alpino-service/2.4.1
# 16   https://tools.clariah.nl/commandlineapplicatio...
# 17      https://tools.clariah.nl/annorepo-client/0.1.3
# 19   https://tools.clariah.nl/commandlineapplicatio...
# 26        https://tools.clariah.nl/audience/developers
# 27   https://tools.clariah.nl/commandlineapplicatio...
# 29   https://tools.clariah.nl/commandlineapplicatio...
# 30         https://mediasuite.clariah.nl/documentation
# 31   https://tools.clariah.nl/commandlineapplicatio...
# 32   http://flat.readthedocs.io/en/latest/installat...
# 34   https://tools.clariah.nl/commandlineapplicatio...
# 36   https://tools.clariah.nl/commandlineapplicatio...
# 39   http://www.sketchengine.co.uk/documentation/wi...
# 41          https://tools.clariah.nl/audience/religion
# 43   https://tools.clariah.nl/commandlineapplicatio...
# 44   https://tools.clariah.nl/commandlineapplicatio...
# 45   https://tools.clariah.nl/commandlineapplicatio...
# 46   https://github.com/CLARIAH/wp6-missieven/blob/...
# 47   https://pagexml.readthedocs.io/en/latest/?badg...
# 48     http://csvw-converter.readthedocs.io/en/latest/
# 49   http://flat.readthedocs.io/en/latest/user_guid...
# 52   https://tools.clariah.nl/commandlineapplicatio...
# 54   https://annorepo-python-client.readthedocs.io/...
# 55   https://nbviewer.org/github/CLARIAH/wp6-missie...
# 57   https://datasetregister.netwerkdigitaalerfgoed...
# 59         https://tools.clariah.nl/audience/education
# 60   https://identifier.overheid.nl/tooi/id/ministe...
# 62   http://flat.readthedocs.io/en/latest/administr...
# 65   https://tools.clariah.nl/commandlineapplicatio...
# 66   https://tools.clariah.nl/commandlineapplicatio...
# 67   https://tools.clariah.nl/commandlineapplicatio...
# 69   https://tools.clariah.nl/commandlineapplicatio...
# 70   https://annotation.github.io/text-fabric/tf/in...
# 77   https://tools.clariah.nl/commandlineapplicatio...
# 78   https://tools.clariah.nl/commandlineapplicatio...
# 80   https://tools.clariah.nl/commandlineapplicatio...
# 81   https://tools.clariah.nl/commandlineapplicatio...
# 83   https://tools.clariah.nl/clariah-fcs-endpoints...
# 84   https://nbviewer.org/github/annotation/banks/b...
# 85   https://tools.clariah.nl/audience/science-rese...
# 86   https://tools.clariah.nl/commandlineapplicatio...
# 87   https://knaw-huc.github.io/annorepo/docs/api-u...
# 90   https://tools.clariah.nl/commandlineapplicatio...
# 92   https://tools.clariah.nl/commandlineapplicatio...
# 93                   http://hdl.handle.net/2066/131547
# 94   https://tools.clariah.nl/commandlineapplicatio...
# 98   https://tools.clariah.nl/commandlineapplicatio...
# 100  https://tools.clariah.nl/commandlineapplicatio...
# 101  https://tools.clariah.nl/commandlineapplicatio...
# 102  https://nbviewer.org/github/Nino-cunei/uruk/bl...
# 105                  http://hdl.handle.net/2066/134833
# 106  https://tools.clariah.nl/commandlineapplicatio...
# 107  https://tools.clariah.nl/commandlineapplicatio...
# 109  https://dane.readthedocs.io/en/latest/intro.ht...
# 110       https://portal.clarin.ivdnt.org/galahad/help
# 112  https://nbviewer.org/github/ETCBC/bhsa/blob/ma...
# 113  https://tools.clariah.nl/commandlineapplicatio...
# 114  https://tools.clariah.nl/commandlineapplicatio...
# 115  https://tools.clariah.nl/commandlineapplicatio...
# 116  http://flat.readthedocs.io/en/latest/?badge=la...
# 117  https://tools.clariah.nl/commandlineapplicatio...
# 118  https://datasetregister.netwerkdigitaalerfgoed...
# 122  https://tools.clariah.nl/commandlineapplicatio...
# 123  https://tools.clariah.nl/commandlineapplicatio...
# 125  https://nbviewer.org/github/Nino-cunei/oldbaby...
# 127  http://www.w3.org/2004/02/skos/core#ConceptScheme
# 128  https://tools.clariah.nl/commandlineapplicatio...
# 131        http://www.w3.org/2004/02/skos/core#Concept
# 135  https://tools.clariah.nl/commandlineapplicatio...
# 136  https://tools.clariah.nl/commandlineapplicatio...
# 137  https://tools.clariah.nl/commandlineapplicatio...
# 138  https://kg.odissei.nl/.well-known/genid/8d5460...
# 141  https://tools.clariah.nl/commandlineapplicatio...
# 145      https://tools.clariah.nl/audience/researchers
# 148  http://foliapy.readthedocs.io/en/latest/?badge...
#
#                                     Entity from File 2  Match Score (%)  \
# 2    https://github.com/MarkDVerhagen/Dutch_healthc...        41.791045
# 4    https://github.com/MarkDVerhagen/Dutch_healthc...        40.287770
# 6    https://github.com/UtrechtUniversity/streetvie...        40.625000
# 7             https://github.com/PerlineDemange/CBS-MR        42.718447
# 9             https://github.com/PerlineDemange/CBS-MR        41.176471
# 10            https://github.com/PerlineDemange/CBS-MR        44.230769
# 11                               https://osf.io/7semh/        49.275362
# 12            https://github.com/PerlineDemange/CBS-MR        43.564356
# 13            https://github.com/PerlineDemange/CBS-MR        43.396226
# 14   https://github.com/MarkDVerhagen/Dutch_healthc...        45.801527
# 15                               https://osf.io/7semh/        48.484848
# 16            https://github.com/PerlineDemange/CBS-MR        41.121495
# 17        https://doi.org/10.1016/j.lanepe.2023.100749        46.666667
# 19            https://github.com/PerlineDemange/CBS-MR        42.307692
# 26                               https://osf.io/gmcjv/        46.153846
# 27   https://github.com/MarkDVerhagen/Dutch_healthc...        39.436620
# 29   https://github.com/MarkDVerhagen/Dutch_healthc...        39.705882
# 30                               https://osf.io/y7tnx/        43.750000
# 31   https://github.com/MarkDVerhagen/Dutch_healthc...        42.105263
# 32                               https://osf.io/xsgdt/        41.975309
# 34   https://github.com/MarkDVerhagen/Dutch_healthc...        43.750000
# 36            https://github.com/PerlineDemange/CBS-MR        40.384615
# 39   https://github.com/UtrechtUniversity/streetvie...        37.398374
# 41                               https://osf.io/gmcjv/        47.619048
# 43            https://github.com/PerlineDemange/CBS-MR        42.718447
# 44   https://github.com/MarkDVerhagen/Dutch_healthc...        41.791045
# 45            https://github.com/PerlineDemange/CBS-MR        43.137255
# 46                 https://github.com/rivm-syso/DIAPER        49.504950
# 47                               https://osf.io/xsgdt/        45.333333
# 48                               https://osf.io/xsgdt/        47.058824
# 49                               https://osf.io/xsgdt/        46.575342
# 52   https://github.com/MarkDVerhagen/Dutch_healthc...        42.748092
# 54                               https://osf.io/xsgdt/        44.155844
# 55   https://github.com/UtrechtUniversity/streetvie...        40.579710
# 57            https://github.com/PerlineDemange/CBS-MR        43.010753
# 59                               https://osf.io/gmcjv/        46.875000
# 60            https://github.com/PerlineDemange/CBS-MR        44.897959
# 62   https://github.com/UtrechtUniversity/streetvie...        42.372881
# 65            https://github.com/PerlineDemange/CBS-MR        42.718447
# 66   https://github.com/MarkDVerhagen/Dutch_healthc...        41.791045
# 67   https://github.com/UtrechtUniversity/streetvie...        45.378151
# 69   https://github.com/MarkDVerhagen/Dutch_healthc...        40.875912
# 70   https://github.com/UtrechtUniversity/streetvie...        49.090909
# 77            https://github.com/PerlineDemange/CBS-MR        42.307692
# 78            https://github.com/PerlineDemange/CBS-MR        40.776699
# 80            https://github.com/PerlineDemange/CBS-MR        41.904762
# 81            https://github.com/PerlineDemange/CBS-MR        41.904762
# 83                               https://osf.io/xsgdt/        47.887324
# 84   https://github.com/UtrechtUniversity/streetvie...        42.962963
# 85   https://github.com/UtrechtUniversity/streetvie...        47.169811
# 86            https://github.com/PerlineDemange/CBS-MR        41.121495
# 87   https://github.com/UtrechtUniversity/streetvie...        46.846847
# 90   https://github.com/MarkDVerhagen/Dutch_healthc...        42.028986
# 92   https://github.com/MarkDVerhagen/Dutch_healthc...        41.176471
# 93        https://doi.org/10.1016/j.lanepe.2023.100749        46.753247
# 94   https://github.com/MarkDVerhagen/Dutch_healthc...        42.962963
# 98   https://github.com/MarkDVerhagen/Dutch_healthc...        39.455782
# 100           https://github.com/PerlineDemange/CBS-MR        40.384615
# 101  https://github.com/MarkDVerhagen/Dutch_healthc...        42.335766
# 102  https://github.com/UtrechtUniversity/streetvie...        43.939394
# 105                    https://doi.org/10.34894/63XWJB        46.875000
# 106           https://github.com/PerlineDemange/CBS-MR        40.384615
# 107           https://github.com/PerlineDemange/CBS-MR        41.584158
# 109  https://github.com/UtrechtUniversity/streetvie...        44.067797
# 110                              https://osf.io/xsgdt/        49.230769
# 112  https://github.com/UtrechtUniversity/streetvie...        44.094488
# 113           https://github.com/PerlineDemange/CBS-MR        40.384615
# 114  https://github.com/MarkDVerhagen/Dutch_healthc...        40.579710
# 115  https://github.com/MarkDVerhagen/Dutch_healthc...        43.076923
# 116                              https://osf.io/xsgdt/        45.070423
# 117           https://github.com/PerlineDemange/CBS-MR        42.718447
# 118           https://github.com/PerlineDemange/CBS-MR        42.857143
# 122           https://github.com/PerlineDemange/CBS-MR        40.776699
# 123           https://github.com/PerlineDemange/CBS-MR        46.464646
# 125  https://github.com/UtrechtUniversity/streetvie...        41.134752
# 127                 https://doi.org/10.7910/DVN/VMMMCL        40.963855
# 128           https://github.com/PerlineDemange/CBS-MR        41.584158
# 131                 https://doi.org/10.7910/DVN/VMMMCL        44.155844
# 135           https://github.com/PerlineDemange/CBS-MR        40.000000
# 136  https://github.com/MarkDVerhagen/Dutch_healthc...        43.283582
# 137  https://github.com/MarkDVerhagen/Dutch_healthc...        42.105263
# 138  https://osf.io/uzcrw?view_only=7114b77c9f8b406...        41.481481
# 141           https://github.com/PerlineDemange/CBS-MR        41.509434
# 145                              https://osf.io/7semh/        48.484848
# 148                              https://osf.io/xsgdt/        43.243243
#
#     Matched
# 2        No
# 4        No
# 6        No
# 7        No
# 9        No
# 10       No
# 11       No
# 12       No
# 13       No
# 14       No
# 15       No
# 16       No
# 17       No
# 19       No
# 26       No
# 27       No
# 29       No
# 30       No
# 31       No
# 32       No
# 34       No
# 36       No
# 39       No
# 41       No
# 43       No
# 44       No
# 45       No
# 46       No
# 47       No
# 48       No
# 49       No
# 52       No
# 54       No
# 55       No
# 57       No
# 59       No
# 60       No
# 62       No
# 65       No
# 66       No
# 67       No
# 69       No
# 70       No
# 77       No
# 78       No
# 80       No
# 81       No
# 83       No
# 84       No
# 85       No
# 86       No
# 87       No
# 90       No
# 92       No
# 93       No
# 94       No
# 98       No
# 100      No
# 101      No
# 102      No
# 105      No
# 106      No
# 107      No
# 109      No
# 110      No
# 112      No
# 113      No
# 114      No
# 115      No
# 116      No
# 117      No
# 118      No
# 122      No
# 123      No
# 125      No
# 127      No
# 128      No
# 131      No
# 135      No
# 136      No
# 137      No
# 138      No
# 141      No
# 145      No
# 148      No
